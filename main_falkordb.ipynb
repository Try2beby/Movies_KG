# %%
import dotenv

dotenv.load_dotenv()

import os
import sys
import logging

logging.basicConfig(stream=sys.stdout, level=logging.INFO)

from langchain_community.graphs import FalkorDBGraph
import pandas as pd

import random

# %%
graph = FalkorDBGraph(database="imdb")
filename = os.path.join(os.getcwd(), "imdb_top_1000.csv")
data = pd.read_csv(filename)

# %%
# Define a function to clean up each column
def clean_column(column_data):
    return column_data.apply(lambda x: x.replace("'", "\\'") if pd.notnull(x) else "NA")


# Assume 'data' is already defined and loaded with pd.read_csv()

# Apply the cleanup function to all necessary columns
data["Series_Title"] = clean_column(data["Series_Title"])
data["Director"] = clean_column(data["Director"])
data["Certificate"] = clean_column(data["Certificate"])
data["Runtime"] = clean_column(data["Runtime"])
data["Genre"] = clean_column(data["Genre"])
data["IMDB_Rating"] = data["IMDB_Rating"].fillna("NA")
data["Released_Year"] = pd.to_numeric(data["Released_Year"], errors="coerce").fillna(-1)

# Clean the star columns
star_columns = ["Star1", "Star2", "Star3", "Star4"]
for column in star_columns:
    data[column] = clean_column(data[column])

# Now, iterate through the DataFrame and construct the graph
for index, row in data.iterrows():
    # Directly use the cleaned data
    movie_title = row["Series_Title"]
    director_name = row["Director"]
    certificate = row["Certificate"]
    runtime = row["Runtime"]
    genre = row["Genre"]
    imdb_rating = row["IMDB_Rating"]
    released_year = int(row["Released_Year"]) if row["Released_Year"] != -1 else "NA"

    # Skip the row if the year is invalid
    if released_year == "NA":
        print(f"Skipping row {index} due to invalid year.")
        continue

    # Create or merge the Movie node
    movie_node = (
        f"MERGE (m:Movie {{"
        f"title: '{movie_title}', "
        f"year: {released_year}, "
        f"certificate: '{certificate}', "
        f"runtime: '{runtime}', "
        f"genre: '{genre}', "
        f"imdb_rating: {imdb_rating}"
        f"}})"
    )

    # Create or merge the Director node
    director_node = f"MERGE (d:Director {{name: '{director_name}'}})"
    directed_by_relation = f"MERGE (d)-[:DIRECTED]->(m)"

    # Create or merge the Star nodes and their relationships
    star_nodes = ""
    starred_in_relations = ""
    for s, star in enumerate(star_columns, start=1):
        star_name = row[star]
        if star_name != "NA":
            star_nodes += f"MERGE (s{s}:Star {{name: '{star_name}'}})\n"
            starred_in_relations += f"MERGE (s{s})-[:STARRED_IN]->(m)\n"

    cypher_query = (
        f"{movie_node} {director_node} {directed_by_relation}\n"
        f"{star_nodes.strip()}\n{starred_in_relations.strip()}"
    )
    # Print the Cypher query
    print(cypher_query)
    graph.query(cypher_query)

# It might be better to refresh the schema once after all operations to optimize performance
graph.refresh_schema()
print("Added graph documents to FalkorDB")
# Out:
# MERGE (m:Movie {title: 'The Shawshank Redemption', year: 1994, certificate: 'A', runtime: '142 min', genre: 'Drama', imdb_rating: 9.3}) MERGE (d:Director {name: 'Frank Darabont'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Tim Robbins'})
# MERGE (s2:Star {name: 'Morgan Freeman'})
# MERGE (s3:Star {name: 'Bob Gunton'})
# MERGE (s4:Star {name: 'William Sadler'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Godfather', year: 1972, certificate: 'A', runtime: '175 min', genre: 'Crime, Drama', imdb_rating: 9.2}) MERGE (d:Director {name: 'Francis Ford Coppola'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Marlon Brando'})
# MERGE (s2:Star {name: 'Al Pacino'})
# MERGE (s3:Star {name: 'James Caan'})
# MERGE (s4:Star {name: 'Diane Keaton'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Dark Knight', year: 2008, certificate: 'UA', runtime: '152 min', genre: 'Action, Crime, Drama', imdb_rating: 9.0}) MERGE (d:Director {name: 'Christopher Nolan'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Christian Bale'})
# MERGE (s2:Star {name: 'Heath Ledger'})
# MERGE (s3:Star {name: 'Aaron Eckhart'})
# MERGE (s4:Star {name: 'Michael Caine'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Godfather: Part II', year: 1974, certificate: 'A', runtime: '202 min', genre: 'Crime, Drama', imdb_rating: 9.0}) MERGE (d:Director {name: 'Francis Ford Coppola'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Al Pacino'})
# MERGE (s2:Star {name: 'Robert De Niro'})
# MERGE (s3:Star {name: 'Robert Duvall'})
# MERGE (s4:Star {name: 'Diane Keaton'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: '12 Angry Men', year: 1957, certificate: 'U', runtime: '96 min', genre: 'Crime, Drama', imdb_rating: 9.0}) MERGE (d:Director {name: 'Sidney Lumet'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Henry Fonda'})
# MERGE (s2:Star {name: 'Lee J. Cobb'})
# MERGE (s3:Star {name: 'Martin Balsam'})
# MERGE (s4:Star {name: 'John Fiedler'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Lord of the Rings: The Return of the King', year: 2003, certificate: 'U', runtime: '201 min', genre: 'Action, Adventure, Drama', imdb_rating: 8.9}) MERGE (d:Director {name: 'Peter Jackson'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Elijah Wood'})
# MERGE (s2:Star {name: 'Viggo Mortensen'})
# MERGE (s3:Star {name: 'Ian McKellen'})
# MERGE (s4:Star {name: 'Orlando Bloom'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Pulp Fiction', year: 1994, certificate: 'A', runtime: '154 min', genre: 'Crime, Drama', imdb_rating: 8.9}) MERGE (d:Director {name: 'Quentin Tarantino'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'John Travolta'})
# MERGE (s2:Star {name: 'Uma Thurman'})
# MERGE (s3:Star {name: 'Samuel L. Jackson'})
# MERGE (s4:Star {name: 'Bruce Willis'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Schindler\'s List', year: 1993, certificate: 'A', runtime: '195 min', genre: 'Biography, Drama, History', imdb_rating: 8.9}) MERGE (d:Director {name: 'Steven Spielberg'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Liam Neeson'})
# MERGE (s2:Star {name: 'Ralph Fiennes'})
# MERGE (s3:Star {name: 'Ben Kingsley'})
# MERGE (s4:Star {name: 'Caroline Goodall'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Inception', year: 2010, certificate: 'UA', runtime: '148 min', genre: 'Action, Adventure, Sci-Fi', imdb_rating: 8.8}) MERGE (d:Director {name: 'Christopher Nolan'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Leonardo DiCaprio'})
# MERGE (s2:Star {name: 'Joseph Gordon-Levitt'})
# MERGE (s3:Star {name: 'Elliot Page'})
# MERGE (s4:Star {name: 'Ken Watanabe'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Fight Club', year: 1999, certificate: 'A', runtime: '139 min', genre: 'Drama', imdb_rating: 8.8}) MERGE (d:Director {name: 'David Fincher'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Brad Pitt'})
# MERGE (s2:Star {name: 'Edward Norton'})
# MERGE (s3:Star {name: 'Meat Loaf'})
# MERGE (s4:Star {name: 'Zach Grenier'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Lord of the Rings: The Fellowship of the Ring', year: 2001, certificate: 'U', runtime: '178 min', genre: 'Action, Adventure, Drama', imdb_rating: 8.8}) MERGE (d:Director {name: 'Peter Jackson'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Elijah Wood'})
# MERGE (s2:Star {name: 'Ian McKellen'})
# MERGE (s3:Star {name: 'Orlando Bloom'})
# MERGE (s4:Star {name: 'Sean Bean'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Forrest Gump', year: 1994, certificate: 'UA', runtime: '142 min', genre: 'Drama, Romance', imdb_rating: 8.8}) MERGE (d:Director {name: 'Robert Zemeckis'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Tom Hanks'})
# MERGE (s2:Star {name: 'Robin Wright'})
# MERGE (s3:Star {name: 'Gary Sinise'})
# MERGE (s4:Star {name: 'Sally Field'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Il buono, il brutto, il cattivo', year: 1966, certificate: 'A', runtime: '161 min', genre: 'Western', imdb_rating: 8.8}) MERGE (d:Director {name: 'Sergio Leone'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Clint Eastwood'})
# MERGE (s2:Star {name: 'Eli Wallach'})
# MERGE (s3:Star {name: 'Lee Van Cleef'})
# MERGE (s4:Star {name: 'Aldo Giuffrè'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Lord of the Rings: The Two Towers', year: 2002, certificate: 'UA', runtime: '179 min', genre: 'Action, Adventure, Drama', imdb_rating: 8.7}) MERGE (d:Director {name: 'Peter Jackson'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Elijah Wood'})
# MERGE (s2:Star {name: 'Ian McKellen'})
# MERGE (s3:Star {name: 'Viggo Mortensen'})
# MERGE (s4:Star {name: 'Orlando Bloom'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Matrix', year: 1999, certificate: 'A', runtime: '136 min', genre: 'Action, Sci-Fi', imdb_rating: 8.7}) MERGE (d:Director {name: 'Lana Wachowski'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Lilly Wachowski'})
# MERGE (s2:Star {name: 'Keanu Reeves'})
# MERGE (s3:Star {name: 'Laurence Fishburne'})
# MERGE (s4:Star {name: 'Carrie-Anne Moss'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Goodfellas', year: 1990, certificate: 'A', runtime: '146 min', genre: 'Biography, Crime, Drama', imdb_rating: 8.7}) MERGE (d:Director {name: 'Martin Scorsese'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Robert De Niro'})
# MERGE (s2:Star {name: 'Ray Liotta'})
# MERGE (s3:Star {name: 'Joe Pesci'})
# MERGE (s4:Star {name: 'Lorraine Bracco'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Star Wars: Episode V - The Empire Strikes Back', year: 1980, certificate: 'UA', runtime: '124 min', genre: 'Action, Adventure, Fantasy', imdb_rating: 8.7}) MERGE (d:Director {name: 'Irvin Kershner'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Mark Hamill'})
# MERGE (s2:Star {name: 'Harrison Ford'})
# MERGE (s3:Star {name: 'Carrie Fisher'})
# MERGE (s4:Star {name: 'Billy Dee Williams'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'One Flew Over the Cuckoo\'s Nest', year: 1975, certificate: 'A', runtime: '133 min', genre: 'Drama', imdb_rating: 8.7}) MERGE (d:Director {name: 'Milos Forman'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Jack Nicholson'})
# MERGE (s2:Star {name: 'Louise Fletcher'})
# MERGE (s3:Star {name: 'Michael Berryman'})
# MERGE (s4:Star {name: 'Peter Brocco'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Hamilton', year: 2020, certificate: 'PG-13', runtime: '160 min', genre: 'Biography, Drama, History', imdb_rating: 8.6}) MERGE (d:Director {name: 'Thomas Kail'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Lin-Manuel Miranda'})
# MERGE (s2:Star {name: 'Phillipa Soo'})
# MERGE (s3:Star {name: 'Leslie Odom Jr.'})
# MERGE (s4:Star {name: 'Renée Elise Goldsberry'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Gisaengchung', year: 2019, certificate: 'A', runtime: '132 min', genre: 'Comedy, Drama, Thriller', imdb_rating: 8.6}) MERGE (d:Director {name: 'Bong Joon Ho'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Kang-ho Song'})
# MERGE (s2:Star {name: 'Lee Sun-kyun'})
# MERGE (s3:Star {name: 'Cho Yeo-jeong'})
# MERGE (s4:Star {name: 'Choi Woo-sik'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Soorarai Pottru', year: 2020, certificate: 'U', runtime: '153 min', genre: 'Drama', imdb_rating: 8.6}) MERGE (d:Director {name: 'Sudha Kongara'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Suriya'})
# MERGE (s2:Star {name: 'Madhavan'})
# MERGE (s3:Star {name: 'Paresh Rawal'})
# MERGE (s4:Star {name: 'Aparna Balamurali'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Interstellar', year: 2014, certificate: 'UA', runtime: '169 min', genre: 'Adventure, Drama, Sci-Fi', imdb_rating: 8.6}) MERGE (d:Director {name: 'Christopher Nolan'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Matthew McConaughey'})
# MERGE (s2:Star {name: 'Anne Hathaway'})
# MERGE (s3:Star {name: 'Jessica Chastain'})
# MERGE (s4:Star {name: 'Mackenzie Foy'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Cidade de Deus', year: 2002, certificate: 'A', runtime: '130 min', genre: 'Crime, Drama', imdb_rating: 8.6}) MERGE (d:Director {name: 'Fernando Meirelles'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Kátia Lund'})
# MERGE (s2:Star {name: 'Alexandre Rodrigues'})
# MERGE (s3:Star {name: 'Leandro Firmino'})
# MERGE (s4:Star {name: 'Matheus Nachtergaele'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Sen to Chihiro no kamikakushi', year: 2001, certificate: 'U', runtime: '125 min', genre: 'Animation, Adventure, Family', imdb_rating: 8.6}) MERGE (d:Director {name: 'Hayao Miyazaki'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Daveigh Chase'})
# MERGE (s2:Star {name: 'Suzanne Pleshette'})
# MERGE (s3:Star {name: 'Miyu Irino'})
# MERGE (s4:Star {name: 'Rumi Hiiragi'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Saving Private Ryan', year: 1998, certificate: 'R', runtime: '169 min', genre: 'Drama, War', imdb_rating: 8.6}) MERGE (d:Director {name: 'Steven Spielberg'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Tom Hanks'})
# MERGE (s2:Star {name: 'Matt Damon'})
# MERGE (s3:Star {name: 'Tom Sizemore'})
# MERGE (s4:Star {name: 'Edward Burns'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Green Mile', year: 1999, certificate: 'A', runtime: '189 min', genre: 'Crime, Drama, Fantasy', imdb_rating: 8.6}) MERGE (d:Director {name: 'Frank Darabont'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Tom Hanks'})
# MERGE (s2:Star {name: 'Michael Clarke Duncan'})
# MERGE (s3:Star {name: 'David Morse'})
# MERGE (s4:Star {name: 'Bonnie Hunt'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'La vita è bella', year: 1997, certificate: 'U', runtime: '116 min', genre: 'Comedy, Drama, Romance', imdb_rating: 8.6}) MERGE (d:Director {name: 'Roberto Benigni'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Roberto Benigni'})
# MERGE (s2:Star {name: 'Nicoletta Braschi'})
# MERGE (s3:Star {name: 'Giorgio Cantarini'})
# MERGE (s4:Star {name: 'Giustino Durano'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Se7en', year: 1995, certificate: 'A', runtime: '127 min', genre: 'Crime, Drama, Mystery', imdb_rating: 8.6}) MERGE (d:Director {name: 'David Fincher'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Morgan Freeman'})
# MERGE (s2:Star {name: 'Brad Pitt'})
# MERGE (s3:Star {name: 'Kevin Spacey'})
# MERGE (s4:Star {name: 'Andrew Kevin Walker'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Silence of the Lambs', year: 1991, certificate: 'A', runtime: '118 min', genre: 'Crime, Drama, Thriller', imdb_rating: 8.6}) MERGE (d:Director {name: 'Jonathan Demme'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Jodie Foster'})
# MERGE (s2:Star {name: 'Anthony Hopkins'})
# MERGE (s3:Star {name: 'Lawrence A. Bonney'})
# MERGE (s4:Star {name: 'Kasi Lemmons'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Star Wars', year: 1977, certificate: 'UA', runtime: '121 min', genre: 'Action, Adventure, Fantasy', imdb_rating: 8.6}) MERGE (d:Director {name: 'George Lucas'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Mark Hamill'})
# MERGE (s2:Star {name: 'Harrison Ford'})
# MERGE (s3:Star {name: 'Carrie Fisher'})
# MERGE (s4:Star {name: 'Alec Guinness'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Seppuku', year: 1962, certificate: 'NA', runtime: '133 min', genre: 'Action, Drama, Mystery', imdb_rating: 8.6}) MERGE (d:Director {name: 'Masaki Kobayashi'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Tatsuya Nakadai'})
# MERGE (s2:Star {name: 'Akira Ishihama'})
# MERGE (s3:Star {name: 'Shima Iwashita'})
# MERGE (s4:Star {name: 'Tetsurô Tanba'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Shichinin no samurai', year: 1954, certificate: 'U', runtime: '207 min', genre: 'Action, Adventure, Drama', imdb_rating: 8.6}) MERGE (d:Director {name: 'Akira Kurosawa'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Toshirô Mifune'})
# MERGE (s2:Star {name: 'Takashi Shimura'})
# MERGE (s3:Star {name: 'Keiko Tsushima'})
# MERGE (s4:Star {name: 'Yukiko Shimazaki'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'It\'s a Wonderful Life', year: 1946, certificate: 'PG', runtime: '130 min', genre: 'Drama, Family, Fantasy', imdb_rating: 8.6}) MERGE (d:Director {name: 'Frank Capra'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'James Stewart'})
# MERGE (s2:Star {name: 'Donna Reed'})
# MERGE (s3:Star {name: 'Lionel Barrymore'})
# MERGE (s4:Star {name: 'Thomas Mitchell'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Joker', year: 2019, certificate: 'A', runtime: '122 min', genre: 'Crime, Drama, Thriller', imdb_rating: 8.5}) MERGE (d:Director {name: 'Todd Phillips'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Joaquin Phoenix'})
# MERGE (s2:Star {name: 'Robert De Niro'})
# MERGE (s3:Star {name: 'Zazie Beetz'})
# MERGE (s4:Star {name: 'Frances Conroy'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Whiplash', year: 2014, certificate: 'A', runtime: '106 min', genre: 'Drama, Music', imdb_rating: 8.5}) MERGE (d:Director {name: 'Damien Chazelle'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Miles Teller'})
# MERGE (s2:Star {name: 'J.K. Simmons'})
# MERGE (s3:Star {name: 'Melissa Benoist'})
# MERGE (s4:Star {name: 'Paul Reiser'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Intouchables', year: 2011, certificate: 'UA', runtime: '112 min', genre: 'Biography, Comedy, Drama', imdb_rating: 8.5}) MERGE (d:Director {name: 'Olivier Nakache'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Éric Toledano'})
# MERGE (s2:Star {name: 'François Cluzet'})
# MERGE (s3:Star {name: 'Omar Sy'})
# MERGE (s4:Star {name: 'Anne Le Ny'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Prestige', year: 2006, certificate: 'U', runtime: '130 min', genre: 'Drama, Mystery, Sci-Fi', imdb_rating: 8.5}) MERGE (d:Director {name: 'Christopher Nolan'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Christian Bale'})
# MERGE (s2:Star {name: 'Hugh Jackman'})
# MERGE (s3:Star {name: 'Scarlett Johansson'})
# MERGE (s4:Star {name: 'Michael Caine'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Departed', year: 2006, certificate: 'A', runtime: '151 min', genre: 'Crime, Drama, Thriller', imdb_rating: 8.5}) MERGE (d:Director {name: 'Martin Scorsese'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Leonardo DiCaprio'})
# MERGE (s2:Star {name: 'Matt Damon'})
# MERGE (s3:Star {name: 'Jack Nicholson'})
# MERGE (s4:Star {name: 'Mark Wahlberg'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Pianist', year: 2002, certificate: 'R', runtime: '150 min', genre: 'Biography, Drama, Music', imdb_rating: 8.5}) MERGE (d:Director {name: 'Roman Polanski'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Adrien Brody'})
# MERGE (s2:Star {name: 'Thomas Kretschmann'})
# MERGE (s3:Star {name: 'Frank Finlay'})
# MERGE (s4:Star {name: 'Emilia Fox'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Gladiator', year: 2000, certificate: 'UA', runtime: '155 min', genre: 'Action, Adventure, Drama', imdb_rating: 8.5}) MERGE (d:Director {name: 'Ridley Scott'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Russell Crowe'})
# MERGE (s2:Star {name: 'Joaquin Phoenix'})
# MERGE (s3:Star {name: 'Connie Nielsen'})
# MERGE (s4:Star {name: 'Oliver Reed'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'American History X', year: 1998, certificate: 'R', runtime: '119 min', genre: 'Drama', imdb_rating: 8.5}) MERGE (d:Director {name: 'Tony Kaye'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Edward Norton'})
# MERGE (s2:Star {name: 'Edward Furlong'})
# MERGE (s3:Star {name: 'Beverly D\'Angelo'})
# MERGE (s4:Star {name: 'Jennifer Lien'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Usual Suspects', year: 1995, certificate: 'A', runtime: '106 min', genre: 'Crime, Mystery, Thriller', imdb_rating: 8.5}) MERGE (d:Director {name: 'Bryan Singer'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Kevin Spacey'})
# MERGE (s2:Star {name: 'Gabriel Byrne'})
# MERGE (s3:Star {name: 'Chazz Palminteri'})
# MERGE (s4:Star {name: 'Stephen Baldwin'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Léon', year: 1994, certificate: 'A', runtime: '110 min', genre: 'Action, Crime, Drama', imdb_rating: 8.5}) MERGE (d:Director {name: 'Luc Besson'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Jean Reno'})
# MERGE (s2:Star {name: 'Gary Oldman'})
# MERGE (s3:Star {name: 'Natalie Portman'})
# MERGE (s4:Star {name: 'Danny Aiello'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Lion King', year: 1994, certificate: 'U', runtime: '88 min', genre: 'Animation, Adventure, Drama', imdb_rating: 8.5}) MERGE (d:Director {name: 'Roger Allers'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Rob Minkoff'})
# MERGE (s2:Star {name: 'Matthew Broderick'})
# MERGE (s3:Star {name: 'Jeremy Irons'})
# MERGE (s4:Star {name: 'James Earl Jones'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Terminator 2: Judgment Day', year: 1991, certificate: 'U', runtime: '137 min', genre: 'Action, Sci-Fi', imdb_rating: 8.5}) MERGE (d:Director {name: 'James Cameron'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Arnold Schwarzenegger'})
# MERGE (s2:Star {name: 'Linda Hamilton'})
# MERGE (s3:Star {name: 'Edward Furlong'})
# MERGE (s4:Star {name: 'Robert Patrick'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Nuovo Cinema Paradiso', year: 1988, certificate: 'U', runtime: '155 min', genre: 'Drama, Romance', imdb_rating: 8.5}) MERGE (d:Director {name: 'Giuseppe Tornatore'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Philippe Noiret'})
# MERGE (s2:Star {name: 'Enzo Cannavale'})
# MERGE (s3:Star {name: 'Antonella Attili'})
# MERGE (s4:Star {name: 'Isa Danieli'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Hotaru no haka', year: 1988, certificate: 'U', runtime: '89 min', genre: 'Animation, Drama, War', imdb_rating: 8.5}) MERGE (d:Director {name: 'Isao Takahata'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Tsutomu Tatsumi'})
# MERGE (s2:Star {name: 'Ayano Shiraishi'})
# MERGE (s3:Star {name: 'Akemi Yamaguchi'})
# MERGE (s4:Star {name: 'Yoshiko Shinohara'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Back to the Future', year: 1985, certificate: 'U', runtime: '116 min', genre: 'Adventure, Comedy, Sci-Fi', imdb_rating: 8.5}) MERGE (d:Director {name: 'Robert Zemeckis'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Michael J. Fox'})
# MERGE (s2:Star {name: 'Christopher Lloyd'})
# MERGE (s3:Star {name: 'Lea Thompson'})
# MERGE (s4:Star {name: 'Crispin Glover'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Once Upon a Time in the West', year: 1968, certificate: 'U', runtime: '165 min', genre: 'Western', imdb_rating: 8.5}) MERGE (d:Director {name: 'Sergio Leone'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Henry Fonda'})
# MERGE (s2:Star {name: 'Charles Bronson'})
# MERGE (s3:Star {name: 'Claudia Cardinale'})
# MERGE (s4:Star {name: 'Jason Robards'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Psycho', year: 1960, certificate: 'A', runtime: '109 min', genre: 'Horror, Mystery, Thriller', imdb_rating: 8.5}) MERGE (d:Director {name: 'Alfred Hitchcock'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Anthony Perkins'})
# MERGE (s2:Star {name: 'Janet Leigh'})
# MERGE (s3:Star {name: 'Vera Miles'})
# MERGE (s4:Star {name: 'John Gavin'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Casablanca', year: 1942, certificate: 'U', runtime: '102 min', genre: 'Drama, Romance, War', imdb_rating: 8.5}) MERGE (d:Director {name: 'Michael Curtiz'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Humphrey Bogart'})
# MERGE (s2:Star {name: 'Ingrid Bergman'})
# MERGE (s3:Star {name: 'Paul Henreid'})
# MERGE (s4:Star {name: 'Claude Rains'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Modern Times', year: 1936, certificate: 'G', runtime: '87 min', genre: 'Comedy, Drama, Family', imdb_rating: 8.5}) MERGE (d:Director {name: 'Charles Chaplin'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Charles Chaplin'})
# MERGE (s2:Star {name: 'Paulette Goddard'})
# MERGE (s3:Star {name: 'Henry Bergman'})
# MERGE (s4:Star {name: 'Tiny Sandford'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'City Lights', year: 1931, certificate: 'G', runtime: '87 min', genre: 'Comedy, Drama, Romance', imdb_rating: 8.5}) MERGE (d:Director {name: 'Charles Chaplin'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Charles Chaplin'})
# MERGE (s2:Star {name: 'Virginia Cherrill'})
# MERGE (s3:Star {name: 'Florence Lee'})
# MERGE (s4:Star {name: 'Harry Myers'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Capharnaüm', year: 2018, certificate: 'A', runtime: '126 min', genre: 'Drama', imdb_rating: 8.4}) MERGE (d:Director {name: 'Nadine Labaki'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Zain Al Rafeea'})
# MERGE (s2:Star {name: 'Yordanos Shiferaw'})
# MERGE (s3:Star {name: 'Boluwatife Treasure Bankole'})
# MERGE (s4:Star {name: 'Kawsar Al Haddad'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Ayla: The Daughter of War', year: 2017, certificate: 'NA', runtime: '125 min', genre: 'Biography, Drama, History', imdb_rating: 8.4}) MERGE (d:Director {name: 'Can Ulkay'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Erdem Can'})
# MERGE (s2:Star {name: 'Çetin Tekindor'})
# MERGE (s3:Star {name: 'Ismail Hacioglu'})
# MERGE (s4:Star {name: 'Kyung-jin Lee'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Vikram Vedha', year: 2017, certificate: 'UA', runtime: '147 min', genre: 'Action, Crime, Drama', imdb_rating: 8.4}) MERGE (d:Director {name: 'Gayatri'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Pushkar'})
# MERGE (s2:Star {name: 'Madhavan'})
# MERGE (s3:Star {name: 'Vijay Sethupathi'})
# MERGE (s4:Star {name: 'Shraddha Srinath'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Kimi no na wa.', year: 2016, certificate: 'U', runtime: '106 min', genre: 'Animation, Drama, Fantasy', imdb_rating: 8.4}) MERGE (d:Director {name: 'Makoto Shinkai'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Ryûnosuke Kamiki'})
# MERGE (s2:Star {name: 'Mone Kamishiraishi'})
# MERGE (s3:Star {name: 'Ryô Narita'})
# MERGE (s4:Star {name: 'Aoi Yûki'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Dangal', year: 2016, certificate: 'U', runtime: '161 min', genre: 'Action, Biography, Drama', imdb_rating: 8.4}) MERGE (d:Director {name: 'Nitesh Tiwari'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Aamir Khan'})
# MERGE (s2:Star {name: 'Sakshi Tanwar'})
# MERGE (s3:Star {name: 'Fatima Sana Shaikh'})
# MERGE (s4:Star {name: 'Sanya Malhotra'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Spider-Man: Into the Spider-Verse', year: 2018, certificate: 'U', runtime: '117 min', genre: 'Animation, Action, Adventure', imdb_rating: 8.4}) MERGE (d:Director {name: 'Bob Persichetti'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Peter Ramsey'})
# MERGE (s2:Star {name: 'Rodney Rothman'})
# MERGE (s3:Star {name: 'Shameik Moore'})
# MERGE (s4:Star {name: 'Jake Johnson'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Avengers: Endgame', year: 2019, certificate: 'UA', runtime: '181 min', genre: 'Action, Adventure, Drama', imdb_rating: 8.4}) MERGE (d:Director {name: 'Anthony Russo'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Joe Russo'})
# MERGE (s2:Star {name: 'Robert Downey Jr.'})
# MERGE (s3:Star {name: 'Chris Evans'})
# MERGE (s4:Star {name: 'Mark Ruffalo'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Avengers: Infinity War', year: 2018, certificate: 'UA', runtime: '149 min', genre: 'Action, Adventure, Sci-Fi', imdb_rating: 8.4}) MERGE (d:Director {name: 'Anthony Russo'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Joe Russo'})
# MERGE (s2:Star {name: 'Robert Downey Jr.'})
# MERGE (s3:Star {name: 'Chris Hemsworth'})
# MERGE (s4:Star {name: 'Mark Ruffalo'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Coco', year: 2017, certificate: 'U', runtime: '105 min', genre: 'Animation, Adventure, Family', imdb_rating: 8.4}) MERGE (d:Director {name: 'Lee Unkrich'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Adrian Molina'})
# MERGE (s2:Star {name: 'Anthony Gonzalez'})
# MERGE (s3:Star {name: 'Gael García Bernal'})
# MERGE (s4:Star {name: 'Benjamin Bratt'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Django Unchained', year: 2012, certificate: 'A', runtime: '165 min', genre: 'Drama, Western', imdb_rating: 8.4}) MERGE (d:Director {name: 'Quentin Tarantino'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Jamie Foxx'})
# MERGE (s2:Star {name: 'Christoph Waltz'})
# MERGE (s3:Star {name: 'Leonardo DiCaprio'})
# MERGE (s4:Star {name: 'Kerry Washington'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Dark Knight Rises', year: 2012, certificate: 'UA', runtime: '164 min', genre: 'Action, Adventure', imdb_rating: 8.4}) MERGE (d:Director {name: 'Christopher Nolan'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Christian Bale'})
# MERGE (s2:Star {name: 'Tom Hardy'})
# MERGE (s3:Star {name: 'Anne Hathaway'})
# MERGE (s4:Star {name: 'Gary Oldman'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: '3 Idiots', year: 2009, certificate: 'UA', runtime: '170 min', genre: 'Comedy, Drama', imdb_rating: 8.4}) MERGE (d:Director {name: 'Rajkumar Hirani'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Aamir Khan'})
# MERGE (s2:Star {name: 'Madhavan'})
# MERGE (s3:Star {name: 'Mona Singh'})
# MERGE (s4:Star {name: 'Sharman Joshi'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Taare Zameen Par', year: 2007, certificate: 'U', runtime: '165 min', genre: 'Drama, Family', imdb_rating: 8.4}) MERGE (d:Director {name: 'Aamir Khan'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Amole Gupte'})
# MERGE (s2:Star {name: 'Darsheel Safary'})
# MERGE (s3:Star {name: 'Aamir Khan'})
# MERGE (s4:Star {name: 'Tisca Chopra'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'WALL·E', year: 2008, certificate: 'U', runtime: '98 min', genre: 'Animation, Adventure, Family', imdb_rating: 8.4}) MERGE (d:Director {name: 'Andrew Stanton'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Ben Burtt'})
# MERGE (s2:Star {name: 'Elissa Knight'})
# MERGE (s3:Star {name: 'Jeff Garlin'})
# MERGE (s4:Star {name: 'Fred Willard'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Lives of Others', year: 2006, certificate: 'A', runtime: '137 min', genre: 'Drama, Mystery, Thriller', imdb_rating: 8.4}) MERGE (d:Director {name: 'Florian Henckel von Donnersmarck'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Ulrich Mühe'})
# MERGE (s2:Star {name: 'Martina Gedeck'})
# MERGE (s3:Star {name: 'Sebastian Koch'})
# MERGE (s4:Star {name: 'Ulrich Tukur'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Oldeuboi', year: 2003, certificate: 'A', runtime: '101 min', genre: 'Action, Drama, Mystery', imdb_rating: 8.4}) MERGE (d:Director {name: 'Chan-wook Park'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Choi Min-sik'})
# MERGE (s2:Star {name: 'Yoo Ji-Tae'})
# MERGE (s3:Star {name: 'Kang Hye-jeong'})
# MERGE (s4:Star {name: 'Kim Byeong-Ok'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Memento', year: 2000, certificate: 'UA', runtime: '113 min', genre: 'Mystery, Thriller', imdb_rating: 8.4}) MERGE (d:Director {name: 'Christopher Nolan'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Guy Pearce'})
# MERGE (s2:Star {name: 'Carrie-Anne Moss'})
# MERGE (s3:Star {name: 'Joe Pantoliano'})
# MERGE (s4:Star {name: 'Mark Boone Junior'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Mononoke-hime', year: 1997, certificate: 'U', runtime: '134 min', genre: 'Animation, Action, Adventure', imdb_rating: 8.4}) MERGE (d:Director {name: 'Hayao Miyazaki'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Yôji Matsuda'})
# MERGE (s2:Star {name: 'Yuriko Ishida'})
# MERGE (s3:Star {name: 'Yûko Tanaka'})
# MERGE (s4:Star {name: 'Billy Crudup'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Once Upon a Time in America', year: 1984, certificate: 'A', runtime: '229 min', genre: 'Crime, Drama', imdb_rating: 8.4}) MERGE (d:Director {name: 'Sergio Leone'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Robert De Niro'})
# MERGE (s2:Star {name: 'James Woods'})
# MERGE (s3:Star {name: 'Elizabeth McGovern'})
# MERGE (s4:Star {name: 'Treat Williams'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Raiders of the Lost Ark', year: 1981, certificate: 'A', runtime: '115 min', genre: 'Action, Adventure', imdb_rating: 8.4}) MERGE (d:Director {name: 'Steven Spielberg'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Harrison Ford'})
# MERGE (s2:Star {name: 'Karen Allen'})
# MERGE (s3:Star {name: 'Paul Freeman'})
# MERGE (s4:Star {name: 'John Rhys-Davies'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Shining', year: 1980, certificate: 'A', runtime: '146 min', genre: 'Drama, Horror', imdb_rating: 8.4}) MERGE (d:Director {name: 'Stanley Kubrick'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Jack Nicholson'})
# MERGE (s2:Star {name: 'Shelley Duvall'})
# MERGE (s3:Star {name: 'Danny Lloyd'})
# MERGE (s4:Star {name: 'Scatman Crothers'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Apocalypse Now', year: 1979, certificate: 'R', runtime: '147 min', genre: 'Drama, Mystery, War', imdb_rating: 8.4}) MERGE (d:Director {name: 'Francis Ford Coppola'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Martin Sheen'})
# MERGE (s2:Star {name: 'Marlon Brando'})
# MERGE (s3:Star {name: 'Robert Duvall'})
# MERGE (s4:Star {name: 'Frederic Forrest'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Alien', year: 1979, certificate: 'R', runtime: '117 min', genre: 'Horror, Sci-Fi', imdb_rating: 8.4}) MERGE (d:Director {name: 'Ridley Scott'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Sigourney Weaver'})
# MERGE (s2:Star {name: 'Tom Skerritt'})
# MERGE (s3:Star {name: 'John Hurt'})
# MERGE (s4:Star {name: 'Veronica Cartwright'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Anand', year: 1971, certificate: 'U', runtime: '122 min', genre: 'Drama, Musical', imdb_rating: 8.4}) MERGE (d:Director {name: 'Hrishikesh Mukherjee'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Rajesh Khanna'})
# MERGE (s2:Star {name: 'Amitabh Bachchan'})
# MERGE (s3:Star {name: 'Sumita Sanyal'})
# MERGE (s4:Star {name: 'Ramesh Deo'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Tengoku to jigoku', year: 1963, certificate: 'NA', runtime: '143 min', genre: 'Crime, Drama, Mystery', imdb_rating: 8.4}) MERGE (d:Director {name: 'Akira Kurosawa'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Toshirô Mifune'})
# MERGE (s2:Star {name: 'Yutaka Sada'})
# MERGE (s3:Star {name: 'Tatsuya Nakadai'})
# MERGE (s4:Star {name: 'Kyôko Kagawa'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', year: 1964, certificate: 'A', runtime: '95 min', genre: 'Comedy', imdb_rating: 8.4}) MERGE (d:Director {name: 'Stanley Kubrick'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Peter Sellers'})
# MERGE (s2:Star {name: 'George C. Scott'})
# MERGE (s3:Star {name: 'Sterling Hayden'})
# MERGE (s4:Star {name: 'Keenan Wynn'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Witness for the Prosecution', year: 1957, certificate: 'U', runtime: '116 min', genre: 'Crime, Drama, Mystery', imdb_rating: 8.4}) MERGE (d:Director {name: 'Billy Wilder'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Tyrone Power'})
# MERGE (s2:Star {name: 'Marlene Dietrich'})
# MERGE (s3:Star {name: 'Charles Laughton'})
# MERGE (s4:Star {name: 'Elsa Lanchester'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Paths of Glory', year: 1957, certificate: 'A', runtime: '88 min', genre: 'Drama, War', imdb_rating: 8.4}) MERGE (d:Director {name: 'Stanley Kubrick'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Kirk Douglas'})
# MERGE (s2:Star {name: 'Ralph Meeker'})
# MERGE (s3:Star {name: 'Adolphe Menjou'})
# MERGE (s4:Star {name: 'George Macready'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Rear Window', year: 1954, certificate: 'U', runtime: '112 min', genre: 'Mystery, Thriller', imdb_rating: 8.4}) MERGE (d:Director {name: 'Alfred Hitchcock'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'James Stewart'})
# MERGE (s2:Star {name: 'Grace Kelly'})
# MERGE (s3:Star {name: 'Wendell Corey'})
# MERGE (s4:Star {name: 'Thelma Ritter'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Sunset Blvd.', year: 1950, certificate: 'Passed', runtime: '110 min', genre: 'Drama, Film-Noir', imdb_rating: 8.4}) MERGE (d:Director {name: 'Billy Wilder'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'William Holden'})
# MERGE (s2:Star {name: 'Gloria Swanson'})
# MERGE (s3:Star {name: 'Erich von Stroheim'})
# MERGE (s4:Star {name: 'Nancy Olson'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Great Dictator', year: 1940, certificate: 'Passed', runtime: '125 min', genre: 'Comedy, Drama, War', imdb_rating: 8.4}) MERGE (d:Director {name: 'Charles Chaplin'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Charles Chaplin'})
# MERGE (s2:Star {name: 'Paulette Goddard'})
# MERGE (s3:Star {name: 'Jack Oakie'})
# MERGE (s4:Star {name: 'Reginald Gardiner'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: '1917', year: 2019, certificate: 'R', runtime: '119 min', genre: 'Drama, Thriller, War', imdb_rating: 8.3}) MERGE (d:Director {name: 'Sam Mendes'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Dean-Charles Chapman'})
# MERGE (s2:Star {name: 'George MacKay'})
# MERGE (s3:Star {name: 'Daniel Mays'})
# MERGE (s4:Star {name: 'Colin Firth'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Tumbbad', year: 2018, certificate: 'A', runtime: '104 min', genre: 'Drama, Fantasy, Horror', imdb_rating: 8.3}) MERGE (d:Director {name: 'Rahi Anil Barve'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Anand Gandhi'})
# MERGE (s2:Star {name: 'Adesh Prasad'})
# MERGE (s3:Star {name: 'Sohum Shah'})
# MERGE (s4:Star {name: 'Jyoti Malshe'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Andhadhun', year: 2018, certificate: 'UA', runtime: '139 min', genre: 'Crime, Drama, Music', imdb_rating: 8.3}) MERGE (d:Director {name: 'Sriram Raghavan'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Ayushmann Khurrana'})
# MERGE (s2:Star {name: 'Tabu'})
# MERGE (s3:Star {name: 'Radhika Apte'})
# MERGE (s4:Star {name: 'Anil Dhawan'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Drishyam', year: 2013, certificate: 'U', runtime: '160 min', genre: 'Crime, Drama, Thriller', imdb_rating: 8.3}) MERGE (d:Director {name: 'Jeethu Joseph'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Mohanlal'})
# MERGE (s2:Star {name: 'Meena'})
# MERGE (s3:Star {name: 'Asha Sharath'})
# MERGE (s4:Star {name: 'Ansiba'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Jagten', year: 2012, certificate: 'R', runtime: '115 min', genre: 'Drama', imdb_rating: 8.3}) MERGE (d:Director {name: 'Thomas Vinterberg'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Mads Mikkelsen'})
# MERGE (s2:Star {name: 'Thomas Bo Larsen'})
# MERGE (s3:Star {name: 'Annika Wedderkopp'})
# MERGE (s4:Star {name: 'Lasse Fogelstrøm'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Jodaeiye Nader az Simin', year: 2011, certificate: 'PG-13', runtime: '123 min', genre: 'Drama', imdb_rating: 8.3}) MERGE (d:Director {name: 'Asghar Farhadi'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Payman Maadi'})
# MERGE (s2:Star {name: 'Leila Hatami'})
# MERGE (s3:Star {name: 'Sareh Bayat'})
# MERGE (s4:Star {name: 'Shahab Hosseini'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Incendies', year: 2010, certificate: 'R', runtime: '131 min', genre: 'Drama, Mystery, War', imdb_rating: 8.3}) MERGE (d:Director {name: 'Denis Villeneuve'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Lubna Azabal'})
# MERGE (s2:Star {name: 'Mélissa Désormeaux-Poulin'})
# MERGE (s3:Star {name: 'Maxim Gaudette'})
# MERGE (s4:Star {name: 'Mustafa Kamel'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Miracle in cell NO.7', year: 2019, certificate: 'TV-14', runtime: '132 min', genre: 'Drama', imdb_rating: 8.3}) MERGE (d:Director {name: 'Mehmet Ada Öztekin'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Aras Bulut Iynemli'})
# MERGE (s2:Star {name: 'Nisa Sofiya Aksongur'})
# MERGE (s3:Star {name: 'Deniz Baysal'})
# MERGE (s4:Star {name: 'Celile Toyon Uysal'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Babam ve Oglum', year: 2005, certificate: 'NA', runtime: '112 min', genre: 'Drama, Family', imdb_rating: 8.3}) MERGE (d:Director {name: 'Çagan Irmak'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Çetin Tekindor'})
# MERGE (s2:Star {name: 'Fikret Kuskan'})
# MERGE (s3:Star {name: 'Hümeyra'})
# MERGE (s4:Star {name: 'Ege Tanman'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Inglourious Basterds', year: 2009, certificate: 'A', runtime: '153 min', genre: 'Adventure, Drama, War', imdb_rating: 8.3}) MERGE (d:Director {name: 'Quentin Tarantino'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Brad Pitt'})
# MERGE (s2:Star {name: 'Diane Kruger'})
# MERGE (s3:Star {name: 'Eli Roth'})
# MERGE (s4:Star {name: 'Mélanie Laurent'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Eternal Sunshine of the Spotless Mind', year: 2004, certificate: 'UA', runtime: '108 min', genre: 'Drama, Romance, Sci-Fi', imdb_rating: 8.3}) MERGE (d:Director {name: 'Michel Gondry'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Jim Carrey'})
# MERGE (s2:Star {name: 'Kate Winslet'})
# MERGE (s3:Star {name: 'Tom Wilkinson'})
# MERGE (s4:Star {name: 'Gerry Robert Byrne'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Amélie', year: 2001, certificate: 'U', runtime: '122 min', genre: 'Comedy, Romance', imdb_rating: 8.3}) MERGE (d:Director {name: 'Jean-Pierre Jeunet'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Audrey Tautou'})
# MERGE (s2:Star {name: 'Mathieu Kassovitz'})
# MERGE (s3:Star {name: 'Rufus'})
# MERGE (s4:Star {name: 'Lorella Cravotta'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Snatch', year: 2000, certificate: 'UA', runtime: '104 min', genre: 'Comedy, Crime', imdb_rating: 8.3}) MERGE (d:Director {name: 'Guy Ritchie'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Jason Statham'})
# MERGE (s2:Star {name: 'Brad Pitt'})
# MERGE (s3:Star {name: 'Benicio Del Toro'})
# MERGE (s4:Star {name: 'Dennis Farina'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# ...
# MERGE (s3:Star {name: 'Janusz Gajos'})
# MERGE (s4:Star {name: 'Jerzy Stuhr'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Falling Down', year: 1993, certificate: 'R', runtime: '113 min', genre: 'Action, Crime, Drama', imdb_rating: 7.6}) MERGE (d:Director {name: 'Joel Schumacher'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Michael Douglas'})
# MERGE (s2:Star {name: 'Robert Duvall'})
# MERGE (s3:Star {name: 'Barbara Hershey'})
# MERGE (s4:Star {name: 'Rachel Ticotin'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Dazed and Confused', year: 1993, certificate: 'U', runtime: '102 min', genre: 'Comedy', imdb_rating: 7.6}) MERGE (d:Director {name: 'Richard Linklater'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Jason London'})
# MERGE (s2:Star {name: 'Wiley Wiggins'})
# MERGE (s3:Star {name: 'Matthew McConaughey'})
# MERGE (s4:Star {name: 'Rory Cochrane'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'My Cousin Vinny', year: 1992, certificate: 'UA', runtime: '120 min', genre: 'Comedy, Crime', imdb_rating: 7.6}) MERGE (d:Director {name: 'Jonathan Lynn'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Joe Pesci'})
# MERGE (s2:Star {name: 'Marisa Tomei'})
# MERGE (s3:Star {name: 'Ralph Macchio'})
# MERGE (s4:Star {name: 'Mitchell Whitfield'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Omohide poro poro', year: 1991, certificate: 'U', runtime: '118 min', genre: 'Animation, Drama, Romance', imdb_rating: 7.6}) MERGE (d:Director {name: 'Isao Takahata'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Miki Imai'})
# MERGE (s2:Star {name: 'Toshirô Yanagiba'})
# MERGE (s3:Star {name: 'Yoko Honna'})
# MERGE (s4:Star {name: 'Mayumi Izuka'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Delicatessen', year: 1991, certificate: 'R', runtime: '99 min', genre: 'Comedy, Crime', imdb_rating: 7.6}) MERGE (d:Director {name: 'Marc Caro'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Jean-Pierre Jeunet'})
# MERGE (s2:Star {name: 'Marie-Laure Dougnac'})
# MERGE (s3:Star {name: 'Dominique Pinon'})
# MERGE (s4:Star {name: 'Pascal Benezech'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Home Alone', year: 1990, certificate: 'U', runtime: '103 min', genre: 'Comedy, Family', imdb_rating: 7.6}) MERGE (d:Director {name: 'Chris Columbus'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Macaulay Culkin'})
# MERGE (s2:Star {name: 'Joe Pesci'})
# MERGE (s3:Star {name: 'Daniel Stern'})
# MERGE (s4:Star {name: 'John Heard'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Godfather: Part III', year: 1990, certificate: 'A', runtime: '162 min', genre: 'Crime, Drama', imdb_rating: 7.6}) MERGE (d:Director {name: 'Francis Ford Coppola'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Al Pacino'})
# MERGE (s2:Star {name: 'Diane Keaton'})
# MERGE (s3:Star {name: 'Andy Garcia'})
# MERGE (s4:Star {name: 'Talia Shire'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'When Harry Met Sally...', year: 1989, certificate: 'UA', runtime: '95 min', genre: 'Comedy, Drama, Romance', imdb_rating: 7.6}) MERGE (d:Director {name: 'Rob Reiner'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Billy Crystal'})
# MERGE (s2:Star {name: 'Meg Ryan'})
# MERGE (s3:Star {name: 'Carrie Fisher'})
# MERGE (s4:Star {name: 'Bruno Kirby'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Little Mermaid', year: 1989, certificate: 'U', runtime: '83 min', genre: 'Animation, Family, Fantasy', imdb_rating: 7.6}) MERGE (d:Director {name: 'Ron Clements'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'John Musker'})
# MERGE (s2:Star {name: 'Jodi Benson'})
# MERGE (s3:Star {name: 'Samuel E. Wright'})
# MERGE (s4:Star {name: 'Rene Auberjonois'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Naked Gun: From the Files of Police Squad!', year: 1988, certificate: 'U', runtime: '85 min', genre: 'Comedy, Crime', imdb_rating: 7.6}) MERGE (d:Director {name: 'David Zucker'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Leslie Nielsen'})
# MERGE (s2:Star {name: 'Priscilla Presley'})
# MERGE (s3:Star {name: 'O.J. Simpson'})
# MERGE (s4:Star {name: 'Ricardo Montalban'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Planes, Trains & Automobiles', year: 1987, certificate: 'U', runtime: '93 min', genre: 'Comedy, Drama', imdb_rating: 7.6}) MERGE (d:Director {name: 'John Hughes'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Steve Martin'})
# MERGE (s2:Star {name: 'John Candy'})
# MERGE (s3:Star {name: 'Laila Robins'})
# MERGE (s4:Star {name: 'Michael McKean'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Lethal Weapon', year: 1987, certificate: 'A', runtime: '109 min', genre: 'Action, Crime, Thriller', imdb_rating: 7.6}) MERGE (d:Director {name: 'Richard Donner'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Mel Gibson'})
# MERGE (s2:Star {name: 'Danny Glover'})
# MERGE (s3:Star {name: 'Gary Busey'})
# MERGE (s4:Star {name: 'Mitchell Ryan'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Blood Simple', year: 1984, certificate: 'A', runtime: '99 min', genre: 'Crime, Drama, Thriller', imdb_rating: 7.6}) MERGE (d:Director {name: 'Joel Coen'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Ethan Coen'})
# MERGE (s2:Star {name: 'John Getz'})
# MERGE (s3:Star {name: 'Frances McDormand'})
# MERGE (s4:Star {name: 'Dan Hedaya'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'On Golden Pond', year: 1981, certificate: 'UA', runtime: '109 min', genre: 'Drama', imdb_rating: 7.6}) MERGE (d:Director {name: 'Mark Rydell'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Katharine Hepburn'})
# MERGE (s2:Star {name: 'Henry Fonda'})
# MERGE (s3:Star {name: 'Jane Fonda'})
# MERGE (s4:Star {name: 'Doug McKeon'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Mad Max 2', year: 1981, certificate: 'A', runtime: '96 min', genre: 'Action, Adventure, Sci-Fi', imdb_rating: 7.6}) MERGE (d:Director {name: 'George Miller'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Mel Gibson'})
# MERGE (s2:Star {name: 'Bruce Spence'})
# MERGE (s3:Star {name: 'Michael Preston'})
# MERGE (s4:Star {name: 'Max Phipps'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Warriors', year: 1979, certificate: 'UA', runtime: '92 min', genre: 'Action, Crime, Thriller', imdb_rating: 7.6}) MERGE (d:Director {name: 'Walter Hill'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Michael Beck'})
# MERGE (s2:Star {name: 'James Remar'})
# MERGE (s3:Star {name: 'Dorsey Wright'})
# MERGE (s4:Star {name: 'Brian Tyler'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Muppet Movie', year: 1979, certificate: 'U', runtime: '95 min', genre: 'Adventure, Comedy, Family', imdb_rating: 7.6}) MERGE (d:Director {name: 'James Frawley'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Jim Henson'})
# MERGE (s2:Star {name: 'Frank Oz'})
# MERGE (s3:Star {name: 'Jerry Nelson'})
# MERGE (s4:Star {name: 'Richard Hunt'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Escape from Alcatraz', year: 1979, certificate: 'A', runtime: '112 min', genre: 'Action, Biography, Crime', imdb_rating: 7.6}) MERGE (d:Director {name: 'Don Siegel'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Clint Eastwood'})
# MERGE (s2:Star {name: 'Patrick McGoohan'})
# MERGE (s3:Star {name: 'Roberts Blossom'})
# MERGE (s4:Star {name: 'Jack Thibeau'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Watership Down', year: 1978, certificate: 'U', runtime: '91 min', genre: 'Animation, Adventure, Drama', imdb_rating: 7.6}) MERGE (d:Director {name: 'Martin Rosen'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'John Hubley'})
# MERGE (s2:Star {name: 'John Hurt'})
# MERGE (s3:Star {name: 'Richard Briers'})
# MERGE (s4:Star {name: 'Ralph Richardson'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Midnight Express', year: 1978, certificate: 'A', runtime: '121 min', genre: 'Biography, Crime, Drama', imdb_rating: 7.6}) MERGE (d:Director {name: 'Alan Parker'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Brad Davis'})
# MERGE (s2:Star {name: 'Irene Miracle'})
# MERGE (s3:Star {name: 'Bo Hopkins'})
# MERGE (s4:Star {name: 'Paolo Bonacelli'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Close Encounters of the Third Kind', year: 1977, certificate: 'U', runtime: '138 min', genre: 'Drama, Sci-Fi', imdb_rating: 7.6}) MERGE (d:Director {name: 'Steven Spielberg'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Richard Dreyfuss'})
# MERGE (s2:Star {name: 'François Truffaut'})
# MERGE (s3:Star {name: 'Teri Garr'})
# MERGE (s4:Star {name: 'Melinda Dillon'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Long Goodbye', year: 1973, certificate: 'A', runtime: '112 min', genre: 'Comedy, Crime, Drama', imdb_rating: 7.6}) MERGE (d:Director {name: 'Robert Altman'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Elliott Gould'})
# MERGE (s2:Star {name: 'Nina van Pallandt'})
# MERGE (s3:Star {name: 'Sterling Hayden'})
# MERGE (s4:Star {name: 'Mark Rydell'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Giù la testa', year: 1971, certificate: 'PG', runtime: '157 min', genre: 'Drama, War, Western', imdb_rating: 7.6}) MERGE (d:Director {name: 'Sergio Leone'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Rod Steiger'})
# MERGE (s2:Star {name: 'James Coburn'})
# MERGE (s3:Star {name: 'Romolo Valli'})
# MERGE (s4:Star {name: 'Maria Monti'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Kelly\'s Heroes', year: 1970, certificate: 'GP', runtime: '144 min', genre: 'Adventure, Comedy, War', imdb_rating: 7.6}) MERGE (d:Director {name: 'Brian G. Hutton'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Clint Eastwood'})
# MERGE (s2:Star {name: 'Telly Savalas'})
# MERGE (s3:Star {name: 'Don Rickles'})
# MERGE (s4:Star {name: 'Carroll O\'Connor'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The Jungle Book', year: 1967, certificate: 'U', runtime: '78 min', genre: 'Animation, Adventure, Family', imdb_rating: 7.6}) MERGE (d:Director {name: 'Wolfgang Reitherman'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Phil Harris'})
# MERGE (s2:Star {name: 'Sebastian Cabot'})
# MERGE (s3:Star {name: 'Louis Prima'})
# MERGE (s4:Star {name: 'Bruce Reitherman'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Blowup', year: 1966, certificate: 'A', runtime: '111 min', genre: 'Drama, Mystery, Thriller', imdb_rating: 7.6}) MERGE (d:Director {name: 'Michelangelo Antonioni'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'David Hemmings'})
# MERGE (s2:Star {name: 'Vanessa Redgrave'})
# MERGE (s3:Star {name: 'Sarah Miles'})
# MERGE (s4:Star {name: 'John Castle'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'A Hard Day\'s Night', year: 1964, certificate: 'U', runtime: '87 min', genre: 'Comedy, Music, Musical', imdb_rating: 7.6}) MERGE (d:Director {name: 'Richard Lester'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'John Lennon'})
# MERGE (s2:Star {name: 'Paul McCartney'})
# MERGE (s3:Star {name: 'George Harrison'})
# MERGE (s4:Star {name: 'Ringo Starr'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Breakfast at Tiffany\'s', year: 1961, certificate: 'A', runtime: '115 min', genre: 'Comedy, Drama, Romance', imdb_rating: 7.6}) MERGE (d:Director {name: 'Blake Edwards'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Audrey Hepburn'})
# MERGE (s2:Star {name: 'George Peppard'})
# MERGE (s3:Star {name: 'Patricia Neal'})
# MERGE (s4:Star {name: 'Buddy Ebsen'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Giant', year: 1956, certificate: 'G', runtime: '201 min', genre: 'Drama, Western', imdb_rating: 7.6}) MERGE (d:Director {name: 'George Stevens'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Elizabeth Taylor'})
# MERGE (s2:Star {name: 'Rock Hudson'})
# MERGE (s3:Star {name: 'James Dean'})
# MERGE (s4:Star {name: 'Carroll Baker'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'From Here to Eternity', year: 1953, certificate: 'Passed', runtime: '118 min', genre: 'Drama, Romance, War', imdb_rating: 7.6}) MERGE (d:Director {name: 'Fred Zinnemann'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Burt Lancaster'})
# MERGE (s2:Star {name: 'Montgomery Clift'})
# MERGE (s3:Star {name: 'Deborah Kerr'})
# MERGE (s4:Star {name: 'Donna Reed'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'Lifeboat', year: 1944, certificate: 'NA', runtime: '97 min', genre: 'Drama, War', imdb_rating: 7.6}) MERGE (d:Director {name: 'Alfred Hitchcock'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Tallulah Bankhead'})
# MERGE (s2:Star {name: 'John Hodiak'})
# MERGE (s3:Star {name: 'Walter Slezak'})
# MERGE (s4:Star {name: 'William Bendix'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# MERGE (m:Movie {title: 'The 39 Steps', year: 1935, certificate: 'NA', runtime: '86 min', genre: 'Crime, Mystery, Thriller', imdb_rating: 7.6}) MERGE (d:Director {name: 'Alfred Hitchcock'}) MERGE (d)-[:DIRECTED]->(m)
# MERGE (s1:Star {name: 'Robert Donat'})
# MERGE (s2:Star {name: 'Madeleine Carroll'})
# MERGE (s3:Star {name: 'Lucie Mannheim'})
# MERGE (s4:Star {name: 'Godfrey Tearle'})
# MERGE (s1)-[:STARRED_IN]->(m)
# MERGE (s2)-[:STARRED_IN]->(m)
# MERGE (s3)-[:STARRED_IN]->(m)
# MERGE (s4)-[:STARRED_IN]->(m)
# Added graph documents to FalkorDB

# %%
# Assume 'data' is already loaded with pd.read_csv()
# movie_names = data['Series_Title'].apply(lambda x: x.replace("'", "\\'")).tolist()
movie_names = data["Series_Title"].tolist()

# Demographic data ranges and options
birth_years_range = (1950, 2005)
genders = ["Male", "Female", "Other"]
locations = ["USA", "UK", "Canada", "Australia", "France", "Germany", "India", "Japan"]

num_persons = 100
num_data_points = 1000

opinions = ["liked", "loved", "ignored", "disliked", "hated"]

# First creating Person Nodes

for i in range(1, num_persons + 1):
    person_name = f"Person {i}"
    birth_year = random.randint(*birth_years_range)
    gender = random.choice(genders)
    location = random.choice(locations)

    person_node = f"CREATE (:Person {{name: '{person_name}', birthYear: {birth_year}, gender: '{gender}', location: '{location}'}})"
    graph.query(person_node)

# Then Matching Person nodes with Movie nodes at random
for _ in range(num_data_points):
    person_index = random.randint(1, num_persons)
    person_name = f"Person {person_index}"

    opinion_edge = random.choice(opinions).upper()
    movie_name = random.choice(movie_names)

    opinion_query = f"MATCH (m:Movie {{title: '{movie_name}'}}), (p:Person {{name: '{person_name}'}})"
    opinion_query += f" MERGE (p)-[:{opinion_edge}]->(m)"

    print(opinion_query)
    graph.query(opinion_query)


graph.refresh_schema()
print("Added graph documents to FalkorDB")
# Out:
# MATCH (m:Movie {title: 'Sweet Smell of Success'}), (p:Person {name: 'Person 42'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Eternal Sunshine of the Spotless Mind'}), (p:Person {name: 'Person 19'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Blues Brothers'}), (p:Person {name: 'Person 8'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Mad Max: Fury Road'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Knives Out'}), (p:Person {name: 'Person 16'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Bringing Up Baby'}), (p:Person {name: 'Person 85'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Spider-Man: Into the Spider-Verse'}), (p:Person {name: 'Person 26'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Moonrise Kingdom'}), (p:Person {name: 'Person 52'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'In the Heat of the Night'}), (p:Person {name: 'Person 1'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Coco'}), (p:Person {name: 'Person 23'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'La règle du jeu'}), (p:Person {name: 'Person 13'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Thor: Ragnarok'}), (p:Person {name: 'Person 18'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'WALL·E'}), (p:Person {name: 'Person 80'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'G.O.R.A.'}), (p:Person {name: 'Person 26'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Perks of Being a Wallflower'}), (p:Person {name: 'Person 38'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Godfather: Part III'}), (p:Person {name: 'Person 37'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Kingsman: The Secret Service'}), (p:Person {name: 'Person 84'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Loving Vincent'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Office Space'}), (p:Person {name: 'Person 32'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'A Christmas Story'}), (p:Person {name: 'Person 16'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Long Goodbye'}), (p:Person {name: 'Person 44'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'In America'}), (p:Person {name: 'Person 47'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Interstellar'}), (p:Person {name: 'Person 98'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Dances with Wolves'}), (p:Person {name: 'Person 75'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Happiness'}), (p:Person {name: 'Person 98'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Harry Potter and the Deathly Hallows: Part 2'}), (p:Person {name: 'Person 89'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Scarface'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Pirates of the Caribbean: The Curse of the Black Pearl'}), (p:Person {name: 'Person 86'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Edward Scissorhands'}), (p:Person {name: 'Person 83'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Alien'}), (p:Person {name: 'Person 12'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Conversation'}), (p:Person {name: 'Person 8'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Knockin\' on Heaven\'s Door'}), (p:Person {name: 'Person 15'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Philomena'}), (p:Person {name: 'Person 46'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'After Hours'}), (p:Person {name: 'Person 23'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Det sjunde inseglet'}), (p:Person {name: 'Person 84'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Ang-ma-reul bo-at-da'}), (p:Person {name: 'Person 47'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Dirty Harry'}), (p:Person {name: 'Person 30'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: '28 Days Later...'}), (p:Person {name: 'Person 29'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Sweet Smell of Success'}), (p:Person {name: 'Person 47'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Mr. Smith Goes to Washington'}), (p:Person {name: 'Person 18'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Ratatouille'}), (p:Person {name: 'Person 45'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The African Queen'}), (p:Person {name: 'Person 97'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Ran'}), (p:Person {name: 'Person 60'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Little Miss Sunshine'}), (p:Person {name: 'Person 67'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Funny Games'}), (p:Person {name: 'Person 27'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Jab We Met'}), (p:Person {name: 'Person 28'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Killing Fields'}), (p:Person {name: 'Person 57'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Treasure of the Sierra Madre'}), (p:Person {name: 'Person 4'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Sin City'}), (p:Person {name: 'Person 77'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Boyz n the Hood'}), (p:Person {name: 'Person 91'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni'}), (p:Person {name: 'Person 65'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Bridges of Madison County'}), (p:Person {name: 'Person 39'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Sherlock Holmes'}), (p:Person {name: 'Person 76'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Deliverance'}), (p:Person {name: 'Person 6'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Boy in the Striped Pyjamas'}), (p:Person {name: 'Person 17'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Barton Fink'}), (p:Person {name: 'Person 54'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Kaguyahime no monogatari'}), (p:Person {name: 'Person 5'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Kis Uykusu'}), (p:Person {name: 'Person 12'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Vizontele'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Pâfekuto burû'}), (p:Person {name: 'Person 89'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Seppuku'}), (p:Person {name: 'Person 13'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Despicable Me'}), (p:Person {name: 'Person 22'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Ed Wood'}), (p:Person {name: 'Person 93'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Rogue One'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Hateful Eight'}), (p:Person {name: 'Person 80'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Gladiator'}), (p:Person {name: 'Person 9'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Delicatessen'}), (p:Person {name: 'Person 46'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'On Golden Pond'}), (p:Person {name: 'Person 71'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Andaz Apna Apna'}), (p:Person {name: 'Person 36'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Raazi'}), (p:Person {name: 'Person 40'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Dead Man\'s Shoes'}), (p:Person {name: 'Person 58'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Les triplettes de Belleville'}), (p:Person {name: 'Person 16'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'A Little Princess'}), (p:Person {name: 'Person 45'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Strangers on a Train'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Theory of Everything'}), (p:Person {name: 'Person 44'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Andrei Rublev'}), (p:Person {name: 'Person 40'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Oldeuboi'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Revenant'}), (p:Person {name: 'Person 2'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Jaws'}), (p:Person {name: 'Person 86'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Manbiki kazoku'}), (p:Person {name: 'Person 81'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Witness for the Prosecution'}), (p:Person {name: 'Person 20'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Home Alone'}), (p:Person {name: 'Person 18'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Lilja 4-ever'}), (p:Person {name: 'Person 37'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Nueve reinas'}), (p:Person {name: 'Person 94'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Glory'}), (p:Person {name: 'Person 75'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: '4 luni, 3 saptamâni si 2 zile'}), (p:Person {name: 'Person 21'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'What\'s Eating Gilbert Grape'}), (p:Person {name: 'Person 89'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Cool Hand Luke'}), (p:Person {name: 'Person 87'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Blind Side'}), (p:Person {name: 'Person 53'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Hamilton'}), (p:Person {name: 'Person 6'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Celda 211'}), (p:Person {name: 'Person 16'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Bound by Honor'}), (p:Person {name: 'Person 68'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Hotaru no haka'}), (p:Person {name: 'Person 37'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'American Beauty'}), (p:Person {name: 'Person 4'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'I Am Sam'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Darbareye Elly'}), (p:Person {name: 'Person 97'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Taxi Driver'}), (p:Person {name: 'Person 32'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Lilja 4-ever'}), (p:Person {name: 'Person 60'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Alien'}), (p:Person {name: 'Person 60'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Sing Street'}), (p:Person {name: 'Person 65'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Terminator 2: Judgment Day'}), (p:Person {name: 'Person 61'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Koe no katachi'}), (p:Person {name: 'Person 24'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Fifth Element'}), (p:Person {name: 'Person 85'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'A Star Is Born'}), (p:Person {name: 'Person 9'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'K.G.F: Chapter 1'}), (p:Person {name: 'Person 80'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Green Book'}), (p:Person {name: 'Person 23'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'My Left Foot: The Story of Christy Brown'}), (p:Person {name: 'Person 89'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Zulu'}), (p:Person {name: 'Person 32'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Jeux d\'enfants'}), (p:Person {name: 'Person 39'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Longest Day'}), (p:Person {name: 'Person 65'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Viskningar och rop'}), (p:Person {name: 'Person 91'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Ôkami kodomo no Ame to Yuki'}), (p:Person {name: 'Person 94'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Treasure of the Sierra Madre'}), (p:Person {name: 'Person 29'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Thin Red Line'}), (p:Person {name: 'Person 68'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'WALL·E'}), (p:Person {name: 'Person 23'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Gentlemen'}), (p:Person {name: 'Person 61'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Pride & Prejudice'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Tonari no Totoro'}), (p:Person {name: 'Person 22'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Black Swan'}), (p:Person {name: 'Person 37'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Udta Punjab'}), (p:Person {name: 'Person 93'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Lives of Others'}), (p:Person {name: 'Person 95'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Longest Day'}), (p:Person {name: 'Person 9'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Seven Pounds'}), (p:Person {name: 'Person 91'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Kick-Ass'}), (p:Person {name: 'Person 5'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Män som hatar kvinnor'}), (p:Person {name: 'Person 36'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Festen'}), (p:Person {name: 'Person 54'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Hobbit: The Desolation of Smaug'}), (p:Person {name: 'Person 96'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Ajeossi'}), (p:Person {name: 'Person 88'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'A Clockwork Orange'}), (p:Person {name: 'Person 31'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Broken Circle Breakdown'}), (p:Person {name: 'Person 59'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Right Stuff'}), (p:Person {name: 'Person 26'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'White Heat'}), (p:Person {name: 'Person 39'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Rain Man'}), (p:Person {name: 'Person 14'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Inception'}), (p:Person {name: 'Person 29'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Bir Zamanlar Anadolu\'da'}), (p:Person {name: 'Person 70'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Zootopia'}), (p:Person {name: 'Person 93'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Bhaag Milkha Bhaag'}), (p:Person {name: 'Person 69'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Wait Until Dark'}), (p:Person {name: 'Person 13'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Sling Blade'}), (p:Person {name: 'Person 36'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Hacksaw Ridge'}), (p:Person {name: 'Person 80'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Breakfast at Tiffany\'s'}), (p:Person {name: 'Person 85'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Bride of Frankenstein'}), (p:Person {name: 'Person 64'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Lion in Winter'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The General'}), (p:Person {name: 'Person 61'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'King Kong'}), (p:Person {name: 'Person 62'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Ba wang bie ji'}), (p:Person {name: 'Person 30'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'True Romance'}), (p:Person {name: 'Person 1'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Jojo Rabbit'}), (p:Person {name: 'Person 6'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Elephant Man'}), (p:Person {name: 'Person 75'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Ladykillers'}), (p:Person {name: 'Person 5'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Funny Games'}), (p:Person {name: 'Person 14'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Clerks'}), (p:Person {name: 'Person 6'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Doctor Zhivago'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Mr. Smith Goes to Washington'}), (p:Person {name: 'Person 6'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'L.A. Confidential'}), (p:Person {name: 'Person 6'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Carlito\'s Way'}), (p:Person {name: 'Person 78'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Paddington 2'}), (p:Person {name: 'Person 5'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Longest Day'}), (p:Person {name: 'Person 7'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Lagaan: Once Upon a Time in India'}), (p:Person {name: 'Person 57'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Gattaca'}), (p:Person {name: 'Person 86'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'A Few Good Men'}), (p:Person {name: 'Person 84'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Pride & Prejudice'}), (p:Person {name: 'Person 25'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Hobbit: The Desolation of Smaug'}), (p:Person {name: 'Person 75'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Ajeossi'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Imitation Game'}), (p:Person {name: 'Person 69'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Kagemusha'}), (p:Person {name: 'Person 7'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Philadelphia Story'}), (p:Person {name: 'Person 74'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Chinatown'}), (p:Person {name: 'Person 89'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Gravity'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Vertigo'}), (p:Person {name: 'Person 100'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Bridges of Madison County'}), (p:Person {name: 'Person 5'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Aliens'}), (p:Person {name: 'Person 79'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'A Christmas Story'}), (p:Person {name: 'Person 91'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Kurenai no buta'}), (p:Person {name: 'Person 24'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'WALL·E'}), (p:Person {name: 'Person 76'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Training Day'}), (p:Person {name: 'Person 56'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Central do Brasil'}), (p:Person {name: 'Person 64'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Zulu'}), (p:Person {name: 'Person 52'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: '(500) Days of Summer'}), (p:Person {name: 'Person 88'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Lion King'}), (p:Person {name: 'Person 86'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: '1917'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Philadelphia'}), (p:Person {name: 'Person 58'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Hachi: A Dog\'s Tale'}), (p:Person {name: 'Person 3'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Duck Soup'}), (p:Person {name: 'Person 75'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Artist'}), (p:Person {name: 'Person 81'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Lord of War'}), (p:Person {name: 'Person 45'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Nuovo Cinema Paradiso'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'JFK'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'One Flew Over the Cuckoo\'s Nest'}), (p:Person {name: 'Person 67'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Jules et Jim'}), (p:Person {name: 'Person 17'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'My Name Is Khan'}), (p:Person {name: 'Person 50'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Kung fu'}), (p:Person {name: 'Person 5'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Jules et Jim'}), (p:Person {name: 'Person 90'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'To Have and Have Not'}), (p:Person {name: 'Person 78'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Airplane!'}), (p:Person {name: 'Person 36'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'No Country for Old Men'}), (p:Person {name: 'Person 75'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Hangover'}), (p:Person {name: 'Person 70'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Lifeboat'}), (p:Person {name: 'Person 3'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Fugitive'}), (p:Person {name: 'Person 30'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Majo no takkyûbin'}), (p:Person {name: 'Person 58'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Black Swan'}), (p:Person {name: 'Person 29'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Gisaengchung'}), (p:Person {name: 'Person 45'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Under sandet'}), (p:Person {name: 'Person 79'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Dev.D'}), (p:Person {name: 'Person 37'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Gattaca'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Fargo'}), (p:Person {name: 'Person 63'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Tangled'}), (p:Person {name: 'Person 52'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Ajeossi'}), (p:Person {name: 'Person 34'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Mississippi Burning'}), (p:Person {name: 'Person 33'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Life of Brian'}), (p:Person {name: 'Person 49'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Bajrangi Bhaijaan'}), (p:Person {name: 'Person 62'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The King\'s Speech'}), (p:Person {name: 'Person 18'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Witness for the Prosecution'}), (p:Person {name: 'Person 64'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Pâfekuto burû'}), (p:Person {name: 'Person 96'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'El ángel exterminador'}), (p:Person {name: 'Person 70'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Tenkû no shiro Rapyuta'}), (p:Person {name: 'Person 66'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Hustler'}), (p:Person {name: 'Person 51'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Hævnen'}), (p:Person {name: 'Person 62'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Batman Begins'}), (p:Person {name: 'Person 7'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Annie Hall'}), (p:Person {name: 'Person 15'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Cat on a Hot Tin Roof'}), (p:Person {name: 'Person 30'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Dip huet seung hung'}), (p:Person {name: 'Person 8'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Close Encounters of the Third Kind'}), (p:Person {name: 'Person 57'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Bound by Honor'}), (p:Person {name: 'Person 57'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Hamilton'}), (p:Person {name: 'Person 20'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Druk'}), (p:Person {name: 'Person 53'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Maltese Falcon'}), (p:Person {name: 'Person 21'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Help'}), (p:Person {name: 'Person 87'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The 39 Steps'}), (p:Person {name: 'Person 22'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Trois couleurs: Rouge'}), (p:Person {name: 'Person 43'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Le samouraï'}), (p:Person {name: 'Person 9'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Midnight Cowboy'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Fugitive'}), (p:Person {name: 'Person 51'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Million Dollar Baby'}), (p:Person {name: 'Person 84'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Sholay'}), (p:Person {name: 'Person 25'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Deadpool 2'}), (p:Person {name: 'Person 31'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'On the Waterfront'}), (p:Person {name: 'Person 63'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Little Mermaid'}), (p:Person {name: 'Person 81'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Dallas Buyers Club'}), (p:Person {name: 'Person 44'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Die Hard'}), (p:Person {name: 'Person 92'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Room'}), (p:Person {name: 'Person 80'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Sicario'}), (p:Person {name: 'Person 49'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Tangled'}), (p:Person {name: 'Person 30'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Whiplash'}), (p:Person {name: 'Person 100'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Tenkû no shiro Rapyuta'}), (p:Person {name: 'Person 46'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Butch Cassidy and the Sundance Kid'}), (p:Person {name: 'Person 2'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Solaris'}), (p:Person {name: 'Person 92'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Lola rennt'}), (p:Person {name: 'Person 55'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Yip Man'}), (p:Person {name: 'Person 50'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Philomena'}), (p:Person {name: 'Person 65'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Andhadhun'}), (p:Person {name: 'Person 65'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Amour'}), (p:Person {name: 'Person 8'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Vikram Vedha'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Forushande'}), (p:Person {name: 'Person 86'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Planes, Trains & Automobiles'}), (p:Person {name: 'Person 67'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Unforgiven'}), (p:Person {name: 'Person 8'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Druk'}), (p:Person {name: 'Person 83'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'East of Eden'}), (p:Person {name: 'Person 12'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Remember the Titans'}), (p:Person {name: 'Person 81'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Chak De! India'}), (p:Person {name: 'Person 41'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Yip Man'}), (p:Person {name: 'Person 89'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Wonder'}), (p:Person {name: 'Person 15'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Billy Elliot'}), (p:Person {name: 'Person 60'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Trainspotting'}), (p:Person {name: 'Person 63'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Toy Story 3'}), (p:Person {name: 'Person 83'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Smultronstället'}), (p:Person {name: 'Person 57'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Gandhi'}), (p:Person {name: 'Person 85'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Saw'}), (p:Person {name: 'Person 1'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Lifeboat'}), (p:Person {name: 'Person 86'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'La règle du jeu'}), (p:Person {name: 'Person 18'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Ang-ma-reul bo-at-da'}), (p:Person {name: 'Person 74'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Contratiempo'}), (p:Person {name: 'Person 32'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Scarface'}), (p:Person {name: 'Person 20'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Fantasia'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Knives Out'}), (p:Person {name: 'Person 23'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Das Experiment'}), (p:Person {name: 'Person 38'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Trois couleurs: Rouge'}), (p:Person {name: 'Person 74'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Guess Who\'s Coming to Dinner'}), (p:Person {name: 'Person 79'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Charade'}), (p:Person {name: 'Person 15'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'M - Eine Stadt sucht einen Mörder'}), (p:Person {name: 'Person 1'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Män som hatar kvinnor'}), (p:Person {name: 'Person 1'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: '2001: A Space Odyssey'}), (p:Person {name: 'Person 28'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Ran'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Les yeux sans visage'}), (p:Person {name: 'Person 9'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Bourne Ultimatum'}), (p:Person {name: 'Person 53'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Carlito\'s Way'}), (p:Person {name: 'Person 28'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Mississippi Burning'}), (p:Person {name: 'Person 45'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Wait Until Dark'}), (p:Person {name: 'Person 72'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Prestige'}), (p:Person {name: 'Person 40'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Sling Blade'}), (p:Person {name: 'Person 98'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'E.T. the Extra-Terrestrial'}), (p:Person {name: 'Person 85'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Jules et Jim'}), (p:Person {name: 'Person 65'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'O Brother, Where Art Thou?'}), (p:Person {name: 'Person 19'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Trois couleurs: Blanc'}), (p:Person {name: 'Person 92'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Lives of Others'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Green Mile'}), (p:Person {name: 'Person 92'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'On Golden Pond'}), (p:Person {name: 'Person 95'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Warrior'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'X: First Class'}), (p:Person {name: 'Person 45'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'L\'avventura'}), (p:Person {name: 'Person 57'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Batman Begins'}), (p:Person {name: 'Person 37'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Lady Vanishes'}), (p:Person {name: 'Person 62'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Dilwale Dulhania Le Jayenge'}), (p:Person {name: 'Person 77'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Almost Famous'}), (p:Person {name: 'Person 20'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Majo no takkyûbin'}), (p:Person {name: 'Person 21'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Boyz n the Hood'}), (p:Person {name: 'Person 36'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Guardians of the Galaxy Vol. 2'}), (p:Person {name: 'Person 16'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'La piel que habito'}), (p:Person {name: 'Person 28'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Les yeux sans visage'}), (p:Person {name: 'Person 100'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Almost Famous'}), (p:Person {name: 'Person 66'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Notebook'}), (p:Person {name: 'Person 72'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Gold Rush'}), (p:Person {name: 'Person 64'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Un long dimanche de fiançailles'}), (p:Person {name: 'Person 20'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Chung Hing sam lam'}), (p:Person {name: 'Person 33'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Gone with the Wind'}), (p:Person {name: 'Person 18'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Sandlot'}), (p:Person {name: 'Person 96'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Shadow of a Doubt'}), (p:Person {name: 'Person 57'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Psycho'}), (p:Person {name: 'Person 15'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Hobbit: An Unexpected Journey'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Wo hu cang long'}), (p:Person {name: 'Person 88'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Catch Me If You Can'}), (p:Person {name: 'Person 12'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Die Hard'}), (p:Person {name: 'Person 100'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Raiders of the Lost Ark'}), (p:Person {name: 'Person 17'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Vikram Vedha'}), (p:Person {name: 'Person 33'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Where Eagles Dare'}), (p:Person {name: 'Person 33'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Harold and Maude'}), (p:Person {name: 'Person 78'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Wrestler'}), (p:Person {name: 'Person 47'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'To Kill a Mockingbird'}), (p:Person {name: 'Person 23'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Misery'}), (p:Person {name: 'Person 74'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Omoide no Mânî'}), (p:Person {name: 'Person 4'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Silver Linings Playbook'}), (p:Person {name: 'Person 51'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Ace in the Hole'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Indiana Jones and the Last Crusade'}), (p:Person {name: 'Person 75'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Bound by Honor'}), (p:Person {name: 'Person 51'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Man Who Would Be King'}), (p:Person {name: 'Person 32'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Judgment at Nuremberg'}), (p:Person {name: 'Person 58'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Victoria'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Rush'}), (p:Person {name: 'Person 69'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Notebook'}), (p:Person {name: 'Person 99'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Boksuneun naui geot'}), (p:Person {name: 'Person 81'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Léon'}), (p:Person {name: 'Person 6'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Game'}), (p:Person {name: 'Person 25'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Kôkaku Kidôtai'}), (p:Person {name: 'Person 25'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Sing Street'}), (p:Person {name: 'Person 7'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Fighter'}), (p:Person {name: 'Person 18'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Mr. Smith Goes to Washington'}), (p:Person {name: 'Person 16'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Before Sunrise'}), (p:Person {name: 'Person 8'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Chhichhore'}), (p:Person {name: 'Person 80'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Iron Giant'}), (p:Person {name: 'Person 95'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Kubo and the Two Strings'}), (p:Person {name: 'Person 41'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Mimi wo sumaseba'}), (p:Person {name: 'Person 44'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Hobbit: An Unexpected Journey'}), (p:Person {name: 'Person 17'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'La passion de Jeanne d\'Arc'}), (p:Person {name: 'Person 83'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Sunrise: A Song of Two Humans'}), (p:Person {name: 'Person 69'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Drishyam'}), (p:Person {name: 'Person 81'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Atonement'}), (p:Person {name: 'Person 51'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Sting'}), (p:Person {name: 'Person 14'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Star Wars: Episode VI - Return of the Jedi'}), (p:Person {name: 'Person 3'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Harry Potter and the Sorcerer\'s Stone'}), (p:Person {name: 'Person 93'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Edward Scissorhands'}), (p:Person {name: 'Person 86'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Taken'}), (p:Person {name: 'Person 82'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Relatos salvajes'}), (p:Person {name: 'Person 37'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Grapes of Wrath'}), (p:Person {name: 'Person 51'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Fanny och Alexander'}), (p:Person {name: 'Person 40'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Bridge on the River Kwai'}), (p:Person {name: 'Person 56'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Auf der anderen Seite'}), (p:Person {name: 'Person 98'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'X: First Class'}), (p:Person {name: 'Person 47'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Room'}), (p:Person {name: 'Person 38'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'A Clockwork Orange'}), (p:Person {name: 'Person 51'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Eskiya'}), (p:Person {name: 'Person 24'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Who Framed Roger Rabbit'}), (p:Person {name: 'Person 10'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Jungfrukällan'}), (p:Person {name: 'Person 40'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Elephant Man'}), (p:Person {name: 'Person 32'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Office Space'}), (p:Person {name: 'Person 62'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Solaris'}), (p:Person {name: 'Person 70'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'V for Vendetta'}), (p:Person {name: 'Person 24'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Per qualche dollaro in più'}), (p:Person {name: 'Person 70'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: '8½'}), (p:Person {name: 'Person 51'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Rosemary\'s Baby'}), (p:Person {name: 'Person 50'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Happiness'}), (p:Person {name: 'Person 51'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Taegukgi hwinalrimyeo'}), (p:Person {name: 'Person 7'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Shadow of a Doubt'}), (p:Person {name: 'Person 28'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Kimi no na wa.'}), (p:Person {name: 'Person 18'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Captain Phillips'}), (p:Person {name: 'Person 67'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Close Encounters of the Third Kind'}), (p:Person {name: 'Person 45'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Scarface'}), (p:Person {name: 'Person 62'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Miracle on 34th Street'}), (p:Person {name: 'Person 22'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Sleepers'}), (p:Person {name: 'Person 38'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The 39 Steps'}), (p:Person {name: 'Person 74'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'X-Men: Days of Future Past'}), (p:Person {name: 'Person 75'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Der Untergang'}), (p:Person {name: 'Person 63'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Harvey'}), (p:Person {name: 'Person 71'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Revenant'}), (p:Person {name: 'Person 36'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Inglourious Basterds'}), (p:Person {name: 'Person 69'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Some Like It Hot'}), (p:Person {name: 'Person 82'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Sherlock Jr.'}), (p:Person {name: 'Person 20'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Aliens'}), (p:Person {name: 'Person 78'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Mulholland Dr.'}), (p:Person {name: 'Person 45'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'What\'s Eating Gilbert Grape'}), (p:Person {name: 'Person 74'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Love and Death'}), (p:Person {name: 'Person 61'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Annie Hall'}), (p:Person {name: 'Person 61'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Up'}), (p:Person {name: 'Person 48'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Dil Chahta Hai'}), (p:Person {name: 'Person 7'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Moana'}), (p:Person {name: 'Person 95'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Belle de jour'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Baby'}), (p:Person {name: 'Person 20'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Planes, Trains & Automobiles'}), (p:Person {name: 'Person 40'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Persona'}), (p:Person {name: 'Person 72'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Odd Couple'}), (p:Person {name: 'Person 90'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Pink'}), (p:Person {name: 'Person 61'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Vampire Hunter D: Bloodlust'}), (p:Person {name: 'Person 20'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'My Fair Lady'}), (p:Person {name: 'Person 52'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Cat on a Hot Tin Roof'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Silver Linings Playbook'}), (p:Person {name: 'Person 16'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'A Few Good Men'}), (p:Person {name: 'Person 12'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Der Untergang'}), (p:Person {name: 'Person 26'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'La piel que habito'}), (p:Person {name: 'Person 6'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Barton Fink'}), (p:Person {name: 'Person 2'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'It\'s a Wonderful Life'}), (p:Person {name: 'Person 85'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'En man som heter Ove'}), (p:Person {name: 'Person 89'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Big Sleep'}), (p:Person {name: 'Person 76'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Tôkyô goddofâzâzu'}), (p:Person {name: 'Person 55'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Blind Side'}), (p:Person {name: 'Person 99'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Gake no ue no Ponyo'}), (p:Person {name: 'Person 84'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Star Trek'}), (p:Person {name: 'Person 46'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Third Man'}), (p:Person {name: 'Person 17'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Taken'}), (p:Person {name: 'Person 50'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Sweet Smell of Success'}), (p:Person {name: 'Person 48'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Der Himmel über Berlin'}), (p:Person {name: 'Person 95'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Kis Uykusu'}), (p:Person {name: 'Person 92'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Taken'}), (p:Person {name: 'Person 52'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Big Sleep'}), (p:Person {name: 'Person 43'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Madeo'}), (p:Person {name: 'Person 5'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Game'}), (p:Person {name: 'Person 33'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Searching'}), (p:Person {name: 'Person 16'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Crimes and Misdemeanors'}), (p:Person {name: 'Person 15'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Munna Bhai M.B.B.S.'}), (p:Person {name: 'Person 5'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Lego Movie'}), (p:Person {name: 'Person 24'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Philadelphia Story'}), (p:Person {name: 'Person 21'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Metropolis'}), (p:Person {name: 'Person 97'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Boondock Saints'}), (p:Person {name: 'Person 59'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Ben-Hur'}), (p:Person {name: 'Person 50'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Do lok tin si'}), (p:Person {name: 'Person 23'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Cabaret'}), (p:Person {name: 'Person 29'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Good Bye Lenin!'}), (p:Person {name: 'Person 41'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Persona'}), (p:Person {name: 'Person 93'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Thin Man'}), (p:Person {name: 'Person 92'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Gold Rush'}), (p:Person {name: 'Person 96'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Papillon'}), (p:Person {name: 'Person 100'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Predator'}), (p:Person {name: 'Person 57'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Out of the Past'}), (p:Person {name: 'Person 85'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Bom Yeoareum Gaeul Gyeoul Geurigo Bom'}), (p:Person {name: 'Person 90'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Trois couleurs: Bleu'}), (p:Person {name: 'Person 98'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Exorcist'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Blazing Saddles'}), (p:Person {name: 'Person 46'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Madeo'}), (p:Person {name: 'Person 50'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Departed'}), (p:Person {name: 'Person 27'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Dilwale Dulhania Le Jayenge'}), (p:Person {name: 'Person 48'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Fault in Our Stars'}), (p:Person {name: 'Person 4'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Little Mermaid'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Fitzcarraldo'}), (p:Person {name: 'Person 52'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Abre los ojos'}), (p:Person {name: 'Person 60'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Usual Suspects'}), (p:Person {name: 'Person 61'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Social Network'}), (p:Person {name: 'Person 60'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Miller\'s Crossing'}), (p:Person {name: 'Person 22'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Magnificent Seven'}), (p:Person {name: 'Person 68'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Big Short'}), (p:Person {name: 'Person 14'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: '28 Days Later...'}), (p:Person {name: 'Person 21'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Synecdoche, New York'}), (p:Person {name: 'Person 71'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Star Trek'}), (p:Person {name: 'Person 76'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Viskningar och rop'}), (p:Person {name: 'Person 26'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Knives Out'}), (p:Person {name: 'Person 13'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Oldeuboi'}), (p:Person {name: 'Person 50'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Notorious'}), (p:Person {name: 'Person 6'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Breakfast at Tiffany\'s'}), (p:Person {name: 'Person 21'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Chung Hing sam lam'}), (p:Person {name: 'Person 5'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Boyhood'}), (p:Person {name: 'Person 34'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Thin Red Line'}), (p:Person {name: 'Person 48'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Atonement'}), (p:Person {name: 'Person 32'}) MERGE (p)-[:LIKED]->(m)
# ...
# MATCH (m:Movie {title: 'The Bourne Supremacy'}), (p:Person {name: 'Person 99'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Kill Bill: Vol. 2'}), (p:Person {name: 'Person 98'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Underground'}), (p:Person {name: 'Person 65'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: '21 Grams'}), (p:Person {name: 'Person 38'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Green Book'}), (p:Person {name: 'Person 78'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Stalag 17'}), (p:Person {name: 'Person 55'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Detachment'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Kari-gurashi no Arietti'}), (p:Person {name: 'Person 26'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Moon'}), (p:Person {name: 'Person 74'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'In America'}), (p:Person {name: 'Person 52'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Last of the Mohicans'}), (p:Person {name: 'Person 38'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Lives of Others'}), (p:Person {name: 'Person 40'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Sleuth'}), (p:Person {name: 'Person 9'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Bound by Honor'}), (p:Person {name: 'Person 38'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Dip huet seung hung'}), (p:Person {name: 'Person 55'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Planet of the Apes'}), (p:Person {name: 'Person 63'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Who Framed Roger Rabbit'}), (p:Person {name: 'Person 65'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'To Kill a Mockingbird'}), (p:Person {name: 'Person 13'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: '21 Grams'}), (p:Person {name: 'Person 22'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'East of Eden'}), (p:Person {name: 'Person 62'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Aliens'}), (p:Person {name: 'Person 53'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Kimi no na wa.'}), (p:Person {name: 'Person 66'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Central do Brasil'}), (p:Person {name: 'Person 8'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'What We Do in the Shadows'}), (p:Person {name: 'Person 90'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Close Encounters of the Third Kind'}), (p:Person {name: 'Person 89'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'To Kill a Mockingbird'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Sound of Metal'}), (p:Person {name: 'Person 2'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'The Hangover'}), (p:Person {name: 'Person 33'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Man Who Would Be King'}), (p:Person {name: 'Person 66'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Sherlock Holmes'}), (p:Person {name: 'Person 25'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Rear Window'}), (p:Person {name: 'Person 32'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Arsenic and Old Lace'}), (p:Person {name: 'Person 9'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Machinist'}), (p:Person {name: 'Person 75'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Soorarai Pottru'}), (p:Person {name: 'Person 10'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Fa yeung nin wah'}), (p:Person {name: 'Person 13'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Vozvrashchenie'}), (p:Person {name: 'Person 29'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Nuovo Cinema Paradiso'}), (p:Person {name: 'Person 1'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Glengarry Glen Ross'}), (p:Person {name: 'Person 3'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Harry Potter and the Deathly Hallows: Part 2'}), (p:Person {name: 'Person 36'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Sen to Chihiro no kamikakushi'}), (p:Person {name: 'Person 68'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'City Lights'}), (p:Person {name: 'Person 85'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Persona'}), (p:Person {name: 'Person 63'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'The Others'}), (p:Person {name: 'Person 91'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Mommy'}), (p:Person {name: 'Person 21'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Kal Ho Naa Ho'}), (p:Person {name: 'Person 49'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Exorcist'}), (p:Person {name: 'Person 96'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Crimes and Misdemeanors'}), (p:Person {name: 'Person 60'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Auf der anderen Seite'}), (p:Person {name: 'Person 1'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'In the Heat of the Night'}), (p:Person {name: 'Person 21'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Third Man'}), (p:Person {name: 'Person 98'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Being There'}), (p:Person {name: 'Person 83'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Hacksaw Ridge'}), (p:Person {name: 'Person 23'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Scarface'}), (p:Person {name: 'Person 59'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Marriage Story'}), (p:Person {name: 'Person 50'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Frost/Nixon'}), (p:Person {name: 'Person 88'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Ah-ga-ssi'}), (p:Person {name: 'Person 44'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Shutter Island'}), (p:Person {name: 'Person 58'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Falling Down'}), (p:Person {name: 'Person 93'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'As Good as It Gets'}), (p:Person {name: 'Person 30'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'A Christmas Story'}), (p:Person {name: 'Person 67'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Kôkaku Kidôtai'}), (p:Person {name: 'Person 6'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Das Experiment'}), (p:Person {name: 'Person 62'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Whiplash'}), (p:Person {name: 'Person 79'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Judgment at Nuremberg'}), (p:Person {name: 'Person 83'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Schindler\'s List'}), (p:Person {name: 'Person 30'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Donnie Darko'}), (p:Person {name: 'Person 75'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'American Psycho'}), (p:Person {name: 'Person 8'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Knockin\' on Heaven\'s Door'}), (p:Person {name: 'Person 71'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Sing Street'}), (p:Person {name: 'Person 58'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Badhaai ho'}), (p:Person {name: 'Person 9'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Invasion of the Body Snatchers'}), (p:Person {name: 'Person 26'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'O Brother, Where Art Thou?'}), (p:Person {name: 'Person 2'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'In a Lonely Place'}), (p:Person {name: 'Person 94'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Miller\'s Crossing'}), (p:Person {name: 'Person 97'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Blade Runner'}), (p:Person {name: 'Person 68'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'English Vinglish'}), (p:Person {name: 'Person 100'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Being There'}), (p:Person {name: 'Person 21'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Once Upon a Time in America'}), (p:Person {name: 'Person 36'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Das Cabinet des Dr. Caligari'}), (p:Person {name: 'Person 22'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Hobbit: The Desolation of Smaug'}), (p:Person {name: 'Person 46'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Paddington 2'}), (p:Person {name: 'Person 98'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Adventures of Robin Hood'}), (p:Person {name: 'Person 74'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'The Outlaw Josey Wales'}), (p:Person {name: 'Person 36'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Ordinary People'}), (p:Person {name: 'Person 81'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Snatch'}), (p:Person {name: 'Person 8'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Toki o kakeru shôjo'}), (p:Person {name: 'Person 22'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Mission: Impossible - Fallout'}), (p:Person {name: 'Person 54'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Les quatre cents coups'}), (p:Person {name: 'Person 63'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Shaun of the Dead'}), (p:Person {name: 'Person 95'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Count of Monte Cristo'}), (p:Person {name: 'Person 32'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Hedwig and the Angry Inch'}), (p:Person {name: 'Person 23'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Der Untergang'}), (p:Person {name: 'Person 16'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'What\'s Eating Gilbert Grape'}), (p:Person {name: 'Person 24'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'The Gold Rush'}), (p:Person {name: 'Person 38'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Terminator'}), (p:Person {name: 'Person 62'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Tenkû no shiro Rapyuta'}), (p:Person {name: 'Person 48'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Kimi no na wa.'}), (p:Person {name: 'Person 28'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Groundhog Day'}), (p:Person {name: 'Person 71'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'First Blood'}), (p:Person {name: 'Person 38'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Harry Potter and the Goblet of Fire'}), (p:Person {name: 'Person 16'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Metropolis'}), (p:Person {name: 'Person 52'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'To Be or Not to Be'}), (p:Person {name: 'Person 4'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Patton'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Rosemary\'s Baby'}), (p:Person {name: 'Person 54'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Heat'}), (p:Person {name: 'Person 99'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Mimi wo sumaseba'}), (p:Person {name: 'Person 10'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Vozvrashchenie'}), (p:Person {name: 'Person 58'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Planet of the Apes'}), (p:Person {name: 'Person 36'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Zwartboek'}), (p:Person {name: 'Person 65'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Saw'}), (p:Person {name: 'Person 77'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'From Here to Eternity'}), (p:Person {name: 'Person 91'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'The Artist'}), (p:Person {name: 'Person 15'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'From Here to Eternity'}), (p:Person {name: 'Person 54'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Ikiru'}), (p:Person {name: 'Person 33'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Belle de jour'}), (p:Person {name: 'Person 10'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Drishyam'}), (p:Person {name: 'Person 1'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Saw'}), (p:Person {name: 'Person 34'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Loving Vincent'}), (p:Person {name: 'Person 54'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'End of Watch'}), (p:Person {name: 'Person 30'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Fiddler on the Roof'}), (p:Person {name: 'Person 34'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Hunt for the Wilderpeople'}), (p:Person {name: 'Person 67'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Schindler\'s List'}), (p:Person {name: 'Person 54'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'El secreto de sus ojos'}), (p:Person {name: 'Person 48'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Ang-ma-reul bo-at-da'}), (p:Person {name: 'Person 3'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Indiana Jones and the Last Crusade'}), (p:Person {name: 'Person 25'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Casablanca'}), (p:Person {name: 'Person 65'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Metropolis'}), (p:Person {name: 'Person 79'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Det sjunde inseglet'}), (p:Person {name: 'Person 75'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'English Vinglish'}), (p:Person {name: 'Person 2'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Funny Games'}), (p:Person {name: 'Person 64'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Sunrise: A Song of Two Humans'}), (p:Person {name: 'Person 64'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Me and Earl and the Dying Girl'}), (p:Person {name: 'Person 81'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Kaze tachinu'}), (p:Person {name: 'Person 72'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Touch of Evil'}), (p:Person {name: 'Person 28'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Incredibles 2'}), (p:Person {name: 'Person 14'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Lost Highway'}), (p:Person {name: 'Person 85'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Life of Brian'}), (p:Person {name: 'Person 95'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'L.A. Confidential'}), (p:Person {name: 'Person 15'}) MERGE (p)-[:LOVED]->(m)
# MATCH (m:Movie {title: 'Mad Max: Fury Road'}), (p:Person {name: 'Person 27'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Vozvrashchenie'}), (p:Person {name: 'Person 61'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Stardust'}), (p:Person {name: 'Person 35'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Planet of the Apes'}), (p:Person {name: 'Person 23'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Hævnen'}), (p:Person {name: 'Person 26'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Perfetti sconosciuti'}), (p:Person {name: 'Person 83'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Dazed and Confused'}), (p:Person {name: 'Person 31'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Good Will Hunting'}), (p:Person {name: 'Person 36'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Babam ve Oglum'}), (p:Person {name: 'Person 34'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Kung fu'}), (p:Person {name: 'Person 56'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Captain America: The Winter Soldier'}), (p:Person {name: 'Person 49'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Il buono, il brutto, il cattivo'}), (p:Person {name: 'Person 56'}) MERGE (p)-[:IGNORED]->(m)
# MATCH (m:Movie {title: 'Dances with Wolves'}), (p:Person {name: 'Person 20'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Victoria'}), (p:Person {name: 'Person 11'}) MERGE (p)-[:HATED]->(m)
# MATCH (m:Movie {title: 'Ford v Ferrari'}), (p:Person {name: 'Person 73'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Remember the Titans'}), (p:Person {name: 'Person 19'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Smultronstället'}), (p:Person {name: 'Person 79'}) MERGE (p)-[:LIKED]->(m)
# MATCH (m:Movie {title: 'Bacheha-Ye aseman'}), (p:Person {name: 'Person 10'}) MERGE (p)-[:DISLIKED]->(m)
# MATCH (m:Movie {title: 'Fanny och Alexander'}), (p:Person {name: 'Person 31'}) MERGE (p)-[:HATED]->(m)
# Added graph documents to FalkorDB

# %%
from langchain_community.chat_models import ChatZhipuAI
from langchain.chains import FalkorDBQAChain

llm = ChatZhipuAI(
    temperature=0,
    zhipuai_api_key=os.getenv("ZHIPUAI_API_KEY"),
    model_name="GLM-4-Flash",
)

chain = FalkorDBQAChain.from_llm(llm, graph=graph, verbose=True)
out1 = chain.run("Which movies did Christopher Nolan direct?")
print(out1)
# Out:
# > Entering new FalkorDBQAChain chain...
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# Generated Cypher:
# MATCH (d:Director {name: 'Christopher Nolan'})-[:DIRECTED]->(m:Movie)
# RETURN m.title
# Full Context:
# [['The Dark Knight'], ['Inception'], ['Interstellar'], ['The Prestige'], ['The Dark Knight Rises'], ['Memento'], ['Batman Begins'], ['Dunkirk']]
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
#
# > Finished chain.
# Christopher Nolan directed "The Dark Knight," "Inception," "Interstellar," "The Prestige," "The Dark Knight Rises," "Memento," "Batman Begins," and "Dunkirk."

# %%
out = chain.run("Who starred in Lifeboat?")
print(out)
# Out:
# > Entering new FalkorDBQAChain chain...
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# Generated Cypher:
# MATCH (m:Movie {title: 'Lifeboat'})<-[:STARRED_IN]-(s:Star)
# RETURN s.name
# Full Context:
# [['Tallulah Bankhead'], ['John Hodiak'], ['Walter Slezak'], ['William Bendix']]
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
#
# > Finished chain.
# Tallulah Bankhead, John Hodiak, Walter Slezak, and William Bendix starred in the film Lifeboat.

# %%
out1 = chain.run("Which movies did person born in year 1975 like?")
print(out1)
out2 = chain.run("Which movies should person born in year 1967 watch?")
print(out2)
# Out:
# > Entering new FalkorDBQAChain chain...
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# Generated Cypher:
# MATCH (p:Person)-[:LIKED]->(m:Movie) WHERE p.birthYear = 1975 RETURN m.title
# Full Context:
# [['Psycho'], ['Bajrangi Bhaijaan'], ['Hauru no ugoku shiro'], ['Hannah and Her Sisters'], ['Notorious'], ['In America'], ['A Bronx Tale'], ["God's Own Country"], ['The Butterfly Effect'], ['Little Women']]
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
#
# > Finished chain.
# The movies that a person born in 1975 might have liked include "Psycho," "Bajrangi Bhaijaan," "Hauru no ugoku shiro," "Hannah and Her Sisters," "Notorious," "In America," "A Bronx Tale," "God's Own Country," "The Butterfly Effect," and "Little Women." These films span various genres and styles, so the preferences of an individual born in 1975 would depend on their personal tastes.
#
#
# > Entering new FalkorDBQAChain chain...
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# Generated Cypher:
# MATCH (p:Person {birthYear: 1967})-[:LIKED]->(m:Movie)
# RETURN m.title
# Full Context:
# [['Baby'], ["The King's Speech"], ['The Princess Bride'], ['Amores perros'], ['Miracle on 34th Street'], ['Rushmore'], ['21 Grams'], ['The 39 Steps'], ['Gone Girl'], ['Festen']]
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
#
# > Finished chain.
# If you were born in 1967, you might enjoy watching classic and critically acclaimed films. Some movies you might consider are "The King's Speech," "The Princess Bride," "Amores Perros," "Miracle on 34th Street," "Rushmore," "21 Grams," "The 39 Steps," "Gone Girl," and "Festen." These films span a range of genres and are known for their storytelling and cinematic quality.

# %%
import gradio as gr

# Assuming your FalkorDBQAChain setup code is correctly initialized here


def ask_question(question):
    # Your function to run the question through the chain and return the output
    output = chain.run(question)
    return output


# Corrected Gradio interface setup
iface = gr.Interface(
    fn=ask_question,
    inputs=gr.Textbox(lines=2, placeholder="Enter your question here..."),
    outputs=gr.Textbox(lines=10, label="Output"),  # Increased the lines for the output
    title="FalkorDB QA System",
    description="Ask any question related to the movie database.",
)

# Launch the Gradio app
iface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# INFO:httpx:HTTP Request: GET http://127.0.0.1:7860/startup-events "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD http://127.0.0.1:7860/ "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://checkip.amazonaws.com/ "HTTP/1.1 200 "
# INFO:httpx:HTTP Request: GET https://api.gradio.app/gradio-messaging/en "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.gradio.app/v2/tunnel-request "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://cdn-media.huggingface.co/frpc-gradio-0.2/frpc_linux_amd64 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# Running on public URL: https://56b23a9c510d9ee36b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# INFO:httpx:HTTP Request: HEAD https://56b23a9c510d9ee36b.gradio.live "HTTP/1.1 200 OK"
# <div><iframe src="https://56b23a9c510d9ee36b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# > Entering new FalkorDBQAChain chain...
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# Generated Cypher:
# MATCH (p:Person)-[:LIKED]->(m:Movie) WHERE p.birthYear = 1975 RETURN m.title
# Full Context:
# [['Psycho'], ['Bajrangi Bhaijaan'], ['Hauru no ugoku shiro'], ['Hannah and Her Sisters'], ['Notorious'], ['In America'], ['A Bronx Tale'], ["God's Own Country"], ['The Butterfly Effect'], ['Little Women']]
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
#
# > Finished chain.
#
#
# > Entering new FalkorDBQAChain chain...
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# Generated Cypher:
# MATCH (p:Person)-[:LIKED]->(m:Movie) RETURN p.name, m.title
# Full Context:
# [['Person 1', 'Nuovo Cinema Paradiso'], ['Person 1', 'Drishyam'], ['Person 1', 'Drishyam'], ['Person 1', 'In the Heat of the Night'], ['Person 1', 'Vicky Donor'], ['Person 2', 'Billy Elliot'], ['Person 3', "Hachi: A Dog's Tale"], ['Person 3', 'Taken'], ['Person 3', 'Dip huet seung hung'], ['Person 3', 'Stagecoach']]
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
#
# > Finished chain.
#
#
# > Entering new FalkorDBQAChain chain...
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# Generated Cypher:
# MATCH (p:Person)-[:LIKED]->(m:Movie) WHERE p.birthYear = 1975 RETURN m.title
# Full Context:
# [['Psycho'], ['Bajrangi Bhaijaan'], ['Hauru no ugoku shiro'], ['Hannah and Her Sisters'], ['Notorious'], ['In America'], ['A Bronx Tale'], ["God's Own Country"], ['The Butterfly Effect'], ['Little Women']]
# INFO:httpx:HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
#
# > Finished chain.
