# %%
import importlib
import movies
import data_describe

importlib.reload(movies)
importlib.reload(data_describe)

MoviesKG = movies.MoviesKG
DataDescribe = data_describe.DataDescribe


import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib_inline import backend_inline
backend_inline.set_matplotlib_formats("svg")

# %%
movies_kg = MoviesKG()

# %%
data = DataDescribe(movies_kg.movies_detailed)
# data.plot_belongs_to_collection()
# data.plot_crew()
# data.plot_genres()
# data.plot_original_country()
# data.plot_production_companies()
data.plot_budget_revenue()
data.plot_vote_count_vote_average()
